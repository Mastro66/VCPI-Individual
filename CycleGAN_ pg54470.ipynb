# %% [markdown]
# # Exploração de GANs para Transferência de Estilo
#
# ### Autor
# - **Autor:** Fernando Daniel de Magalhães Pipa Alves
# - **Número:** pg54470
# - **Perfil** Computação Gráfica
# - **Disciplina:** Visão por Computador
# - **Instituição:** Universidade do Minho

# %% [markdown]
# ## 1. Introdução
# Este projeto pretende explorar Redes Adversárias Generativas (GANs) para a transferência de estilo de imagens. O objetivo é transformar imagens de Pokémon no estilo de pinturas de artistas famosos, como Van Gogh. Este trabalho baseia-se em métodos como CycleGAN.
#
# ## 2. Imports necessários e informação do Device
# Uma vez que nas aulas usamos pyTorch, o trabalho foi desenvolvido usando essa biblioteca.
# Este projeto usou CUDA, através do PC, sem recurso a Google Colab. A gráfica utilizada foi uma NVIDIA GeForce GTX 1650 Ti, conforme está explícito embaixo.

# %% [markdown]
# Para conseguir correr este arquivo, é necessário ter instalado o torch, torchvision, pillow, matplotlib, numpy e torchsummary. No seu kernel efetuar !pip install torch torchvision pillow matplotlib numpy torchsummary

# %%
import os
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

from torchsummary import summary

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print('Device:', device)
print('PyTorch version:', torch.__version__)
print('CUDA version:', torch.version.cuda)
print('cuDNN version:', torch.backends.cudnn.version())
print('CUDA available:', torch.cuda.is_available())
print('CUDA device count:', torch.cuda.device_count())
print('CUDA device name:', torch.cuda.get_device_name())
# Out:
# Device: cuda
# PyTorch version: 2.2.1+cu118
# CUDA version: 11.8
# cuDNN version: 8700
# CUDA available: True
# CUDA device count: 1
# CUDA device name: NVIDIA GeForce GTX 1650 Ti

# %% [markdown]
# ## 3. Preparação do Dataset
# Nesta secção, descreve-se a preparação dos datasets, que incluem imagens de Pokémon e pinturas de Van Gogh.
#
# ### 3.1 Diretórios das Imagens e Informações dos Datasets
# Definem-se os caminhos para os diretórios onde se encontram as imagens de Pokémon e Van Gogh, assim como as suas informações.

# %%
# Directories of images
pokemon_directory = 'C:/Users/ferna/OneDrive/Ambiente de Trabalho/4 ano 2 sem/CG/Visão por Computador e Processamento Imagem/Visão por computador/VCPI_Individual/Pokemon/pokemon/pokemon/all_images'
van_gogh_directory = 'C:/Users/ferna/OneDrive/Ambiente de Trabalho/4 ano 2 sem/CG/Visão por Computador e Processamento Imagem/Visão por computador/VCPI_Individual/VincentVanGogh/VincentVanGogh/Saint Remy'

print('Pokemon directory:', pokemon_directory)
print('Van Gogh directory:', van_gogh_directory)

print('Number of Pokemon images:', len(os.listdir(pokemon_directory)))
print('Number of Van Gogh images:', len(os.listdir(van_gogh_directory)))


print('Example of Pokemon image shape:', np.array(Image.open(os.path.join(pokemon_directory, os.listdir(pokemon_directory)[0]))).shape)
print('Example of Van Gogh image shape:', np.array(Image.open(os.path.join(van_gogh_directory, os.listdir(van_gogh_directory)[0]))).shape)
# Out:
# Pokemon directory: C:/Users/ferna/OneDrive/Ambiente de Trabalho/4 ano 2 sem/CG/Visão por Computador e Processamento Imagem/Visão por computador/VCPI_Individual/Pokemon/pokemon/pokemon/all_images
# Van Gogh directory: C:/Users/ferna/OneDrive/Ambiente de Trabalho/4 ano 2 sem/CG/Visão por Computador e Processamento Imagem/Visão por computador/VCPI_Individual/VincentVanGogh/VincentVanGogh/Saint Remy
# Number of Pokemon images: 819
# Number of Van Gogh images: 143
# Example of Pokemon image shape: (256, 256, 4)
# Example of Van Gogh image shape: (1024, 785, 3)

# %% [markdown]
# ### 3.2 Transformações e Augmentação de Dados
# As imagens são redimensionadas, transformadas em tensor e normalizadas. Adicionalmente, aplica-se um flip horizontal aleatório para aumentar a variedade dos dados de treino.

# %%
# Transformations with Data Augmentation
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %% [markdown]
# ### 3.3 Classe de Dataset Personalizada
# Define-se uma classe de dataset personalizada para carregar as imagens de Pokémon e Van Gogh, limitando o número de imagens de Pokémon a 100.
#
# Também são apresentados como são as imagens de Pokémon e as imagens do pinto Van Gogh.

# %%
class ImageDataset(Dataset):
    def __init__(self, root_pokemon, root_painter, transform=None, limit=None):
        self.transform = transform
        self.files_pokemon = [os.path.join(root_pokemon, f) for f in os.listdir(root_pokemon) if f.endswith(('.png', '.jpg'))][:limit]
        self.files_painter = [os.path.join(root_painter, f) for f in os.listdir(root_painter) if f.endswith(('.png', '.jpg'))]

    def __getitem__(self, index):
        item_pokemon = self.transform(Image.open(self.files_pokemon[index % len(self.files_pokemon)]).convert('RGB'))
        item_painter = self.transform(Image.open(self.files_painter[index % len(self.files_painter)]).convert('RGB'))
        return {'A': item_pokemon, 'B': item_painter}

    def __len__(self):
        return max(len(self.files_pokemon), len(self.files_painter))
    
 # Função de visualização sem transformações
def visualize_random_images(pokemon_dir, painter_dir, num_images=2):
    pokemon_images = [os.path.join(pokemon_dir, f) for f in os.listdir(pokemon_dir) if f.endswith(('.png', '.jpg'))]
    painter_images = [os.path.join(painter_dir, f) for f in os.listdir(painter_dir) if f.endswith(('.png', '.jpg'))]

    random_pokemon_images = random.sample(pokemon_images, num_images)
    random_painter_images = random.sample(painter_images, num_images)

    fig, axes = plt.subplots(2, num_images, figsize=(10, 5))

    for i, img_path in enumerate(random_pokemon_images):
        img = Image.open(img_path).convert('RGB')
        axes[0, i].imshow(img)
        axes[0, i].set_title('Pokémon')
        axes[0, i].axis('off')

    for i, img_path in enumerate(random_painter_images):
        img = Image.open(img_path).convert('RGB')
        axes[1, i].imshow(img)
        axes[1, i].set_title('Van Gogh')
        axes[1, i].axis('off')

    plt.tight_layout()
    plt.show()

# Visualizar as imagens aleatórias
visualize_random_images(pokemon_directory, van_gogh_directory)

# %% [markdown]
# ### 3.4 Criação dos DataLoaders
# Os DataLoaders são criados para carregar as imagens durante o treino, garantindo que são embaralhadas.

# %%
pokemon_limit = 100
dataloader = DataLoader(ImageDataset(pokemon_directory, van_gogh_directory, transform=transform, limit=pokemon_limit), batch_size=1, shuffle=True, num_workers=0)

# %% [markdown]
# ## 4. Arquitetura dos Modelos
# Nesta secção, detalha-se a arquitetura das redes geradoras e discriminadoras utilizadas.

# %% [markdown]
# ### 4.1 Gerador
# O gerador transforma uma imagem de um domínio para outro, neste caso, de Pokémon para um estilo de pintura. A arquitetura do gerador é composta por uma camada inicial de convolução, seguida por camadas de downsampling, blocos residuais, camadas de upsampling e uma camada de saída.

# %%
class Generator(nn.Module):
    def __init__(self, input_nc, output_nc):
        super(Generator, self).__init__()

        # Bloco de convolução inicial
        model = [
            nn.Conv2d(input_nc, 64, kernel_size=7, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        ]

        # Downsampling
        in_features = 64
        out_features = in_features * 2
        for _ in range(2):
            model += [
                nn.Conv2d(in_features, out_features, kernel_size=3, stride=2, padding=1, bias=False),
                nn.BatchNorm2d(out_features),
                nn.ReLU(inplace=True)
            ]
            in_features = out_features
            out_features = in_features * 2

        # Blocos residuais
        for _ in range(6):
            model += [
                nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1, bias=False),
                nn.BatchNorm2d(in_features),
                nn.ReLU(inplace=True)
            ]

        # Upsampling
        out_features = in_features // 2
        for _ in range(2):
            model += [
                nn.ConvTranspose2d(in_features, out_features, kernel_size=3, stride=2, padding=1, output_padding=1, bias=False),
                nn.BatchNorm2d(out_features),
                nn.ReLU(inplace=True)
            ]
            in_features = out_features
            out_features = in_features // 2

        # Camada de saída
        model += [nn.Conv2d(64, output_nc, kernel_size=7, padding=3), nn.Tanh()]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### 4.2 Discriminador
# O discriminador distingue entre imagens reais e geradas. A arquitetura do discriminador é composta por várias camadas de convolução que reduzem progressivamente a dimensão da imagem, até uma camada final que produz um mapa de probabilidade indicando se as regiões da imagem são reais ou falsas.

# %%
class Discriminator(nn.Module):
    def __init__(self, input_nc):
        super(Discriminator, self).__init__()
        model = [
            nn.Conv2d(input_nc, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True)
        ]
        in_features = 64
        out_features = in_features * 2
        for _ in range(3):
            model += [
                nn.Conv2d(in_features, out_features, kernel_size=4, stride=2, padding=1, bias=False),
                nn.BatchNorm2d(out_features),
                nn.LeakyReLU(0.2, inplace=True)
            ]
            in_features = out_features
            out_features = in_features * 2
        model += [nn.Conv2d(in_features, 1, kernel_size=4, stride=1, padding=1, bias=False)]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Mostrar a Arquitetura dos Modelos
#
# Para este trabalho, utilizou-se apenas a transformação de Pokémon para o estilo de pinturas de Van Gogh. A transformação inversa (pinturas de Van Gogh para Pokémon) será considerada para trabalhos futuros.

# %%
print('Generator:')
summary(Generator(3, 3).to(device), (3, 256, 256))
# Out:
# Generator:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 256, 256]           9,408
#        BatchNorm2d-2         [-1, 64, 256, 256]             128
#               ReLU-3         [-1, 64, 256, 256]               0
#             Conv2d-4        [-1, 128, 128, 128]          73,728
#        BatchNorm2d-5        [-1, 128, 128, 128]             256
#               ReLU-6        [-1, 128, 128, 128]               0
#             Conv2d-7          [-1, 256, 64, 64]         294,912
#        BatchNorm2d-8          [-1, 256, 64, 64]             512
#               ReLU-9          [-1, 256, 64, 64]               0
#            Conv2d-10          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-11          [-1, 256, 64, 64]             512
#              ReLU-12          [-1, 256, 64, 64]               0
#            Conv2d-13          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-14          [-1, 256, 64, 64]             512
#              ReLU-15          [-1, 256, 64, 64]               0
#            Conv2d-16          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-17          [-1, 256, 64, 64]             512
#              ReLU-18          [-1, 256, 64, 64]               0
#            Conv2d-19          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-20          [-1, 256, 64, 64]             512
#              ReLU-21          [-1, 256, 64, 64]               0
#            Conv2d-22          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-23          [-1, 256, 64, 64]             512
#              ReLU-24          [-1, 256, 64, 64]               0
#            Conv2d-25          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-26          [-1, 256, 64, 64]             512
#              ReLU-27          [-1, 256, 64, 64]               0
#   ConvTranspose2d-28        [-1, 128, 128, 128]         294,912
#       BatchNorm2d-29        [-1, 128, 128, 128]             256
#              ReLU-30        [-1, 128, 128, 128]               0
#   ConvTranspose2d-31         [-1, 64, 256, 256]          73,728
#       BatchNorm2d-32         [-1, 64, 256, 256]             128
#              ReLU-33         [-1, 64, 256, 256]               0
#            Conv2d-34          [-1, 3, 256, 256]           9,411
#              Tanh-35          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 4,299,395
# Trainable params: 4,299,395
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 459.00
# Params size (MB): 16.40
# Estimated Total Size (MB): 476.15
# ----------------------------------------------------------------

# %%
print('Discriminator:')
summary(Discriminator(3).to(device), (3, 256, 256))
# Out:
# Discriminator:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           3,072
#          LeakyReLU-2         [-1, 64, 128, 128]               0
#             Conv2d-3          [-1, 128, 64, 64]         131,072
#        BatchNorm2d-4          [-1, 128, 64, 64]             256
#          LeakyReLU-5          [-1, 128, 64, 64]               0
#             Conv2d-6          [-1, 256, 32, 32]         524,288
#        BatchNorm2d-7          [-1, 256, 32, 32]             512
#          LeakyReLU-8          [-1, 256, 32, 32]               0
#             Conv2d-9          [-1, 512, 16, 16]       2,097,152
#       BatchNorm2d-10          [-1, 512, 16, 16]           1,024
#         LeakyReLU-11          [-1, 512, 16, 16]               0
#            Conv2d-12            [-1, 1, 15, 15]           8,192
# ================================================================
# Total params: 2,765,568
# Trainable params: 2,765,568
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 37.00
# Params size (MB): 10.55
# Estimated Total Size (MB): 48.30
# ----------------------------------------------------------------

# %% [markdown]
# ## 5. Inicialização e Treino do Modelo
# Nesta secção, inicializam-se e treinam-se os modelos.

# %% [markdown]
# ### 5.1 Inicialização dos Pesos
# Inicializam-se os pesos das redes para garantir uma distribuição normal. Esta técnica é importante para assegurar que os pesos começam com valores que permitem ao modelo aprender de forma eficiente.

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ### 5.2 Definição das Funções de Perda
# Utilizam-se três funções de perda diferentes:
#
# - criterion_GAN: Mede a diferença entre as previsões do discriminador para imagens reais e geradas, usando Mean Squared Error (MSE).
# - criterion_cycle: Calcula a diferença entre a imagem original e a imagem reconstruída após passar pelo gerador de ida e volta, utilizando L1 Loss. Esta perda garante que a imagem reconstruída seja semelhante à original.
# - criterion_identity: Verifica se o gerador mantém a identidade da imagem quando a imagem de destino é fornecida como entrada, utilizando L1 Loss.

# %%
criterion_GAN = nn.MSELoss().to(device)
criterion_cycle = nn.L1Loss().to(device)
criterion_identity = nn.L1Loss().to(device)

# %% [markdown]
# ### 5.3 Inicialização dos Modelos e Otimizadores
# Inicializam-se os modelos e otimizadores necessários para o treino.

# %%
netG_A2B = Generator(input_nc=3, output_nc=3).to(device)
netG_B2A = Generator(input_nc=3, output_nc=3).to(device)
netD_A = Discriminator(input_nc=3).to(device)
netD_B = Discriminator(input_nc=3).to(device)

netG_A2B.apply(weights_init_normal)
netG_B2A.apply(weights_init_normal)
netD_A.apply(weights_init_normal)
netD_B.apply(weights_init_normal)

optimizer_G = optim.Adam(itertools.chain(netG_A2B.parameters(), netG_B2A.parameters()), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_A = optim.Adam(netD_A.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_B = optim.Adam(netD_B.parameters(), lr=0.0002, betas=(0.5, 0.999))

scheduler_G = optim.lr_scheduler.StepLR(optimizer_G, step_size=100, gamma=0.5)
scheduler_D_A = optim.lr_scheduler.StepLR(optimizer_D_A, step_size=100, gamma=0.5)
scheduler_D_B = optim.lr_scheduler.StepLR(optimizer_D_B, step_size=100, gamma=0.5)

# %% [markdown]
# ## 6. Ciclo de Treino
# Nesta secção, descreve-se o ciclo de treino do modelo. Cada época envolve os seguintes passos:
#
# 1. Geradores: Atualizam-se os geradores para gerar imagens que enganam os discriminadores.
#
# - Identidade: A imagem gerada a partir da imagem de destino deve ser igual à própria imagem de destino.
# - Adversarial: A imagem gerada deve ser classificada como real pelo discriminador.
# - Ciclo: A imagem original deve ser recuperada após passar pelos dois geradores (ciclo de ida e volta).
#
# 2. Discriminadores: Atualizam-se os discriminadores para distinguir entre imagens reais e geradas.
#
# - A imagem real deve ser classificada como real.
# - A imagem gerada deve ser classificada como falsa.
# 3. Atualização dos Otimizadores: Os otimizadores são atualizados após o cálculo das perdas.

# %% [markdown]
# ### 6.1 Treino Principal
# Treina-se o modelo ao longo de várias épocas utilizando o ciclo de treino definido.
#
# O treino foi efetuado com 100 épocas, o qual demorou 134 minutos a correr. Os valores loss foram guardados para no fim serem discutidos.

# %%
# Função para calcular a média móvel
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    sma = np.convolve(values, weights, 'valid')
    return sma

# Função para mostrar as perdas
def plot_losses(losses, window_size=50):
    min_len = min(len(losses['D_A']), len(losses['D_B']), len(losses['G']))
    loss_D_A_smooth = moving_average(losses['D_A'][:min_len], window_size)
    loss_D_B_smooth = moving_average(losses['D_B'][:min_len], window_size)
    loss_G_smooth = moving_average(losses['G'][:min_len], window_size)
    steps = range(1, len(loss_D_A_smooth) + 1)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.plot(steps, loss_D_A_smooth, label='Loss D_A')
    plt.xlabel('Step')
    plt.ylabel('Loss D_A')
    plt.title('Loss D_A (Smoothed)')
    plt.legend()

    plt.subplot(1, 3, 2)
    plt.plot(steps, loss_D_B_smooth, label='Loss D_B')
    plt.xlabel('Step')
    plt.ylabel('Loss D_B')
    plt.title('Loss D_B (Smoothed)')
    plt.legend()

    plt.subplot(1, 3, 3)
    plt.plot(steps, loss_G_smooth, label='Loss G')
    plt.xlabel('Step')
    plt.ylabel('Loss G')
    plt.title('Loss G (Smoothed)')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Variáveis para armazenar as perdas
losses = {'D_A': [], 'D_B': [], 'G': []}

def train_epoch(epoch, dataloader, netG_A2B, netG_B2A, netD_A, netD_B, optimizer_G, optimizer_D_A, optimizer_D_B, criterion_GAN, criterion_cycle, criterion_identity, device):
    for i, batch in enumerate(dataloader):
        real_A = batch['A'].to(device)
        real_B = batch['B'].to(device)

        valid = torch.ones((real_A.size(0), *netD_A(real_A).shape[1:]), requires_grad=False).to(device)
        fake = torch.zeros((real_A.size(0), *netD_A(real_A).shape[1:]), requires_grad=False).to(device)

        optimizer_G.zero_grad()

        loss_id_A = criterion_identity(netG_B2A(real_A), real_A) * 5.0
        loss_id_B = criterion_identity(netG_A2B(real_B), real_B) * 5.0

        fake_B = netG_A2B(real_A)
        loss_GAN_A2B = criterion_GAN(netD_B(fake_B), valid)
        fake_A = netG_B2A(real_B)
        loss_GAN_B2A = criterion_GAN(netD_A(fake_A), valid)

        rec_A = netG_B2A(fake_B)
        loss_cycle_A = criterion_cycle(rec_A, real_A) * 10.0
        rec_B = netG_A2B(fake_A)
        loss_cycle_B = criterion_cycle(rec_B, real_B) * 10.0

        loss_G = loss_id_A + loss_id_B + loss_GAN_A2B + loss_GAN_B2A + loss_cycle_A + loss_cycle_B
        loss_G.backward()
        optimizer_G.step()

        optimizer_D_A.zero_grad()
        loss_real_A = criterion_GAN(netD_A(real_A), valid)
        loss_fake_A = criterion_GAN(netD_A(fake_A.detach()), fake)
        loss_D_A = (loss_real_A + loss_fake_A) * 0.5
        loss_D_A.backward()
        optimizer_D_A.step()

        optimizer_D_B.zero_grad()
        loss_real_B = criterion_GAN(netD_B(real_B), valid)
        loss_fake_B = criterion_GAN(netD_B(fake_B.detach()), fake)
        loss_D_B = (loss_real_B + loss_fake_B) * 0.5
        loss_D_B.backward()
        optimizer_D_B.step()

        if (i + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(dataloader)}], '
                  f'Loss D_A: {loss_D_A.item():.4f}, Loss D_B: {loss_D_B.item():.4f}, '
                  f'Loss G: {loss_G.item():.4f}')

    # Armazenar as perdas após cada época
    losses['D_A'].append(loss_D_A.item())
    losses['D_B'].append(loss_D_B.item())
    losses['G'].append(loss_G.item())

    scheduler_G.step()
    scheduler_D_A.step()
    scheduler_D_B.step()

# Treino Principal
num_epochs = 100
pokemon_limit = 100
dataloader = DataLoader(ImageDataset(pokemon_directory, van_gogh_directory, transform=transform, limit=pokemon_limit), batch_size=1, shuffle=True, num_workers=0)

for epoch in range(num_epochs):
    train_epoch(epoch, dataloader, netG_A2B, netG_B2A, netD_A, netD_B, optimizer_G, optimizer_D_A, optimizer_D_B, criterion_GAN, criterion_cycle, criterion_identity, device)
# Out:
# Epoch [1/100], Step [10/143], Loss D_A: 1.0888, Loss D_B: 1.4035, Loss G: 17.0447
# Epoch [1/100], Step [20/143], Loss D_A: 0.7549, Loss D_B: 1.4329, Loss G: 12.9580
# Epoch [1/100], Step [30/143], Loss D_A: 0.3404, Loss D_B: 0.7799, Loss G: 11.6685
# Epoch [1/100], Step [40/143], Loss D_A: 0.2577, Loss D_B: 0.4725, Loss G: 10.0215
# Epoch [1/100], Step [50/143], Loss D_A: 0.1832, Loss D_B: 0.4889, Loss G: 9.5822
# Epoch [1/100], Step [60/143], Loss D_A: 0.4153, Loss D_B: 0.3399, Loss G: 10.9383
# Epoch [1/100], Step [70/143], Loss D_A: 0.3248, Loss D_B: 0.3691, Loss G: 9.0027
# Epoch [1/100], Step [80/143], Loss D_A: 0.1930, Loss D_B: 0.2946, Loss G: 8.1933
# Epoch [1/100], Step [90/143], Loss D_A: 0.3027, Loss D_B: 0.3198, Loss G: 8.5670
# Epoch [1/100], Step [100/143], Loss D_A: 0.1970, Loss D_B: 0.2158, Loss G: 7.1207
# Epoch [1/100], Step [110/143], Loss D_A: 0.2332, Loss D_B: 0.1976, Loss G: 8.6199
# Epoch [1/100], Step [120/143], Loss D_A: 0.3522, Loss D_B: 0.4396, Loss G: 8.5103
# Epoch [1/100], Step [130/143], Loss D_A: 0.2103, Loss D_B: 0.2838, Loss G: 8.4776
# Epoch [1/100], Step [140/143], Loss D_A: 0.2653, Loss D_B: 0.3311, Loss G: 9.3304
# Epoch [2/100], Step [10/143], Loss D_A: 0.1871, Loss D_B: 0.3532, Loss G: 8.3174
# Epoch [2/100], Step [20/143], Loss D_A: 0.1912, Loss D_B: 0.2404, Loss G: 7.6705
# Epoch [2/100], Step [30/143], Loss D_A: 0.2884, Loss D_B: 0.2267, Loss G: 10.2494
# Epoch [2/100], Step [40/143], Loss D_A: 0.2234, Loss D_B: 0.2705, Loss G: 6.6612
# Epoch [2/100], Step [50/143], Loss D_A: 0.2897, Loss D_B: 0.1873, Loss G: 6.5330
# Epoch [2/100], Step [60/143], Loss D_A: 0.1843, Loss D_B: 0.2007, Loss G: 7.3841
# Epoch [2/100], Step [70/143], Loss D_A: 0.1587, Loss D_B: 0.1553, Loss G: 10.5494
# Epoch [2/100], Step [80/143], Loss D_A: 0.2352, Loss D_B: 0.2519, Loss G: 6.7644
# Epoch [2/100], Step [90/143], Loss D_A: 0.2336, Loss D_B: 0.2679, Loss G: 6.5281
# Epoch [2/100], Step [100/143], Loss D_A: 0.3803, Loss D_B: 0.3520, Loss G: 13.3297
# Epoch [2/100], Step [110/143], Loss D_A: 0.3352, Loss D_B: 0.2380, Loss G: 7.5516
# Epoch [2/100], Step [120/143], Loss D_A: 0.2002, Loss D_B: 0.2177, Loss G: 9.1895
# Epoch [2/100], Step [130/143], Loss D_A: 0.1783, Loss D_B: 0.1422, Loss G: 7.7486
# Epoch [2/100], Step [140/143], Loss D_A: 0.3217, Loss D_B: 0.2321, Loss G: 7.1994
# Epoch [3/100], Step [10/143], Loss D_A: 0.1772, Loss D_B: 0.3784, Loss G: 6.9636
# Epoch [3/100], Step [20/143], Loss D_A: 0.2524, Loss D_B: 0.2720, Loss G: 11.0409
# Epoch [3/100], Step [30/143], Loss D_A: 0.2632, Loss D_B: 0.2902, Loss G: 7.3937
# Epoch [3/100], Step [40/143], Loss D_A: 0.2484, Loss D_B: 0.1423, Loss G: 9.2039
# Epoch [3/100], Step [50/143], Loss D_A: 0.1654, Loss D_B: 0.1619, Loss G: 9.4817
# Epoch [3/100], Step [60/143], Loss D_A: 0.4488, Loss D_B: 0.2644, Loss G: 7.0995
# Epoch [3/100], Step [70/143], Loss D_A: 0.1961, Loss D_B: 0.1082, Loss G: 6.4742
# Epoch [3/100], Step [80/143], Loss D_A: 0.2961, Loss D_B: 0.2142, Loss G: 12.2557
# Epoch [3/100], Step [90/143], Loss D_A: 0.1767, Loss D_B: 0.1101, Loss G: 10.3868
# Epoch [3/100], Step [100/143], Loss D_A: 0.2930, Loss D_B: 0.4846, Loss G: 9.8351
# Epoch [3/100], Step [110/143], Loss D_A: 0.3211, Loss D_B: 0.2724, Loss G: 7.5181
# Epoch [3/100], Step [120/143], Loss D_A: 0.2363, Loss D_B: 0.2491, Loss G: 6.2336
# Epoch [3/100], Step [130/143], Loss D_A: 0.1410, Loss D_B: 0.1913, Loss G: 10.7395
# Epoch [3/100], Step [140/143], Loss D_A: 0.3159, Loss D_B: 0.2571, Loss G: 9.6204
# Epoch [4/100], Step [10/143], Loss D_A: 0.2023, Loss D_B: 0.1593, Loss G: 6.8113
# Epoch [4/100], Step [20/143], Loss D_A: 0.1736, Loss D_B: 0.1654, Loss G: 8.0994
# Epoch [4/100], Step [30/143], Loss D_A: 0.2121, Loss D_B: 0.2412, Loss G: 7.1470
# Epoch [4/100], Step [40/143], Loss D_A: 0.1895, Loss D_B: 0.2079, Loss G: 7.1434
# Epoch [4/100], Step [50/143], Loss D_A: 0.2899, Loss D_B: 0.3108, Loss G: 6.7136
# Epoch [4/100], Step [60/143], Loss D_A: 0.2535, Loss D_B: 0.1398, Loss G: 7.0403
# Epoch [4/100], Step [70/143], Loss D_A: 0.1335, Loss D_B: 0.1537, Loss G: 6.5086
# Epoch [4/100], Step [80/143], Loss D_A: 0.1944, Loss D_B: 0.1779, Loss G: 7.9088
# Epoch [4/100], Step [90/143], Loss D_A: 0.1610, Loss D_B: 0.2672, Loss G: 6.9260
# Epoch [4/100], Step [100/143], Loss D_A: 0.2081, Loss D_B: 0.1830, Loss G: 9.0490
# Epoch [4/100], Step [110/143], Loss D_A: 0.0946, Loss D_B: 0.1334, Loss G: 10.0701
# Epoch [4/100], Step [120/143], Loss D_A: 0.1638, Loss D_B: 0.2605, Loss G: 8.5069
# Epoch [4/100], Step [130/143], Loss D_A: 0.1068, Loss D_B: 0.1926, Loss G: 7.0944
# Epoch [4/100], Step [140/143], Loss D_A: 0.2952, Loss D_B: 0.1557, Loss G: 7.3128
# Epoch [5/100], Step [10/143], Loss D_A: 0.1679, Loss D_B: 0.4144, Loss G: 5.8780
# Epoch [5/100], Step [20/143], Loss D_A: 0.1460, Loss D_B: 0.2402, Loss G: 7.3088
# Epoch [5/100], Step [30/143], Loss D_A: 0.0811, Loss D_B: 0.2400, Loss G: 7.9677
# Epoch [5/100], Step [40/143], Loss D_A: 0.1653, Loss D_B: 0.2747, Loss G: 6.5136
# Epoch [5/100], Step [50/143], Loss D_A: 0.1184, Loss D_B: 0.1624, Loss G: 7.8594
# Epoch [5/100], Step [60/143], Loss D_A: 1.0154, Loss D_B: 0.1844, Loss G: 8.0530
# Epoch [5/100], Step [70/143], Loss D_A: 0.1865, Loss D_B: 0.1720, Loss G: 6.8046
# Epoch [5/100], Step [80/143], Loss D_A: 0.1094, Loss D_B: 0.2543, Loss G: 9.8062
# Epoch [5/100], Step [90/143], Loss D_A: 0.2349, Loss D_B: 0.1603, Loss G: 6.9996
# Epoch [5/100], Step [100/143], Loss D_A: 0.1196, Loss D_B: 0.2402, Loss G: 6.6492
# Epoch [5/100], Step [110/143], Loss D_A: 0.2580, Loss D_B: 0.0680, Loss G: 8.1795
# Epoch [5/100], Step [120/143], Loss D_A: 0.1660, Loss D_B: 0.0970, Loss G: 6.4462
# Epoch [5/100], Step [130/143], Loss D_A: 0.1460, Loss D_B: 0.0833, Loss G: 8.9259
# Epoch [5/100], Step [140/143], Loss D_A: 0.1296, Loss D_B: 0.1627, Loss G: 6.5333
# Epoch [6/100], Step [10/143], Loss D_A: 0.1011, Loss D_B: 0.0528, Loss G: 8.9099
# Epoch [6/100], Step [20/143], Loss D_A: 0.1667, Loss D_B: 0.0769, Loss G: 8.4256
# Epoch [6/100], Step [30/143], Loss D_A: 0.2849, Loss D_B: 0.2757, Loss G: 7.1519
# Epoch [6/100], Step [40/143], Loss D_A: 0.0606, Loss D_B: 0.0882, Loss G: 9.5616
# Epoch [6/100], Step [50/143], Loss D_A: 0.1949, Loss D_B: 0.0996, Loss G: 7.8309
# Epoch [6/100], Step [60/143], Loss D_A: 0.1713, Loss D_B: 0.2290, Loss G: 9.3696
# Epoch [6/100], Step [70/143], Loss D_A: 0.2539, Loss D_B: 0.2051, Loss G: 8.9236
# Epoch [6/100], Step [80/143], Loss D_A: 0.1619, Loss D_B: 0.1904, Loss G: 7.4140
# Epoch [6/100], Step [90/143], Loss D_A: 0.1515, Loss D_B: 0.1660, Loss G: 9.9276
# Epoch [6/100], Step [100/143], Loss D_A: 0.1200, Loss D_B: 0.0841, Loss G: 6.2074
# Epoch [6/100], Step [110/143], Loss D_A: 0.1720, Loss D_B: 0.1350, Loss G: 9.1050
# Epoch [6/100], Step [120/143], Loss D_A: 0.2178, Loss D_B: 0.1081, Loss G: 7.3811
# Epoch [6/100], Step [130/143], Loss D_A: 0.4613, Loss D_B: 0.2602, Loss G: 8.4530
# Epoch [6/100], Step [140/143], Loss D_A: 0.1545, Loss D_B: 0.1653, Loss G: 6.5848
# Epoch [7/100], Step [10/143], Loss D_A: 0.1083, Loss D_B: 0.1200, Loss G: 10.3118
# Epoch [7/100], Step [20/143], Loss D_A: 0.2143, Loss D_B: 0.0914, Loss G: 6.4863
# Epoch [7/100], Step [30/143], Loss D_A: 0.2710, Loss D_B: 0.2079, Loss G: 6.8797
# Epoch [7/100], Step [40/143], Loss D_A: 0.1006, Loss D_B: 0.1753, Loss G: 6.9196
# Epoch [7/100], Step [50/143], Loss D_A: 0.0802, Loss D_B: 0.1707, Loss G: 8.5397
# Epoch [7/100], Step [60/143], Loss D_A: 0.4785, Loss D_B: 0.2433, Loss G: 7.0467
# Epoch [7/100], Step [70/143], Loss D_A: 0.0999, Loss D_B: 0.1581, Loss G: 7.5544
# Epoch [7/100], Step [80/143], Loss D_A: 0.1639, Loss D_B: 0.1322, Loss G: 6.2795
# Epoch [7/100], Step [90/143], Loss D_A: 0.1579, Loss D_B: 0.1891, Loss G: 6.6290
# Epoch [7/100], Step [100/143], Loss D_A: 0.2678, Loss D_B: 0.1609, Loss G: 6.3299
# Epoch [7/100], Step [110/143], Loss D_A: 0.3819, Loss D_B: 0.4550, Loss G: 9.9593
# Epoch [7/100], Step [120/143], Loss D_A: 0.1215, Loss D_B: 0.1542, Loss G: 15.3603
# Epoch [7/100], Step [130/143], Loss D_A: 0.1486, Loss D_B: 0.1561, Loss G: 6.8323
# Epoch [7/100], Step [140/143], Loss D_A: 0.3068, Loss D_B: 0.1644, Loss G: 7.9969
# Epoch [8/100], Step [10/143], Loss D_A: 0.1465, Loss D_B: 0.1584, Loss G: 7.7705
# Epoch [8/100], Step [20/143], Loss D_A: 0.1331, Loss D_B: 0.1502, Loss G: 7.1149
# Epoch [8/100], Step [30/143], Loss D_A: 0.0553, Loss D_B: 0.1608, Loss G: 10.4605
# Epoch [8/100], Step [40/143], Loss D_A: 0.1119, Loss D_B: 0.2723, Loss G: 9.6796
# Epoch [8/100], Step [50/143], Loss D_A: 0.2014, Loss D_B: 0.1514, Loss G: 7.9902
# Epoch [8/100], Step [60/143], Loss D_A: 0.0892, Loss D_B: 0.1400, Loss G: 7.6506
# Epoch [8/100], Step [70/143], Loss D_A: 0.1692, Loss D_B: 0.1282, Loss G: 9.7034
# Epoch [8/100], Step [80/143], Loss D_A: 0.2962, Loss D_B: 0.1761, Loss G: 9.3118
# Epoch [8/100], Step [90/143], Loss D_A: 0.1053, Loss D_B: 0.2914, Loss G: 7.8733
# Epoch [8/100], Step [100/143], Loss D_A: 0.2490, Loss D_B: 0.1738, Loss G: 9.2557
# Epoch [8/100], Step [110/143], Loss D_A: 0.1411, Loss D_B: 0.1486, Loss G: 7.8268
# Epoch [8/100], Step [120/143], Loss D_A: 0.1121, Loss D_B: 0.1129, Loss G: 6.3973
# Epoch [8/100], Step [130/143], Loss D_A: 0.2428, Loss D_B: 0.4524, Loss G: 5.9107
# Epoch [8/100], Step [140/143], Loss D_A: 0.1000, Loss D_B: 0.1495, Loss G: 8.3018
# Epoch [9/100], Step [10/143], Loss D_A: 0.1226, Loss D_B: 0.1131, Loss G: 7.7822
# Epoch [9/100], Step [20/143], Loss D_A: 0.1646, Loss D_B: 0.2631, Loss G: 6.1631
# Epoch [9/100], Step [30/143], Loss D_A: 0.2136, Loss D_B: 0.2826, Loss G: 6.1352
# Epoch [9/100], Step [40/143], Loss D_A: 0.1258, Loss D_B: 0.3039, Loss G: 6.2220
# Epoch [9/100], Step [50/143], Loss D_A: 0.0664, Loss D_B: 0.2127, Loss G: 7.1485
# Epoch [9/100], Step [60/143], Loss D_A: 0.0999, Loss D_B: 0.1884, Loss G: 7.6937
# Epoch [9/100], Step [70/143], Loss D_A: 0.1521, Loss D_B: 0.2610, Loss G: 6.0959
# Epoch [9/100], Step [80/143], Loss D_A: 0.0873, Loss D_B: 0.2324, Loss G: 5.9060
# Epoch [9/100], Step [90/143], Loss D_A: 0.1691, Loss D_B: 0.2294, Loss G: 6.4353
# Epoch [9/100], Step [100/143], Loss D_A: 0.1477, Loss D_B: 0.2992, Loss G: 7.0475
# Epoch [9/100], Step [110/143], Loss D_A: 0.1239, Loss D_B: 0.1425, Loss G: 10.1675
# Epoch [9/100], Step [120/143], Loss D_A: 0.0930, Loss D_B: 0.1673, Loss G: 7.7429
# Epoch [9/100], Step [130/143], Loss D_A: 0.1156, Loss D_B: 0.1764, Loss G: 7.0761
# Epoch [9/100], Step [140/143], Loss D_A: 0.1034, Loss D_B: 0.1663, Loss G: 5.4200
# Epoch [10/100], Step [10/143], Loss D_A: 0.1974, Loss D_B: 0.1564, Loss G: 7.6967
# Epoch [10/100], Step [20/143], Loss D_A: 0.1444, Loss D_B: 0.2291, Loss G: 6.4643
# Epoch [10/100], Step [30/143], Loss D_A: 0.1073, Loss D_B: 0.1972, Loss G: 7.4242
# Epoch [10/100], Step [40/143], Loss D_A: 0.2838, Loss D_B: 0.1155, Loss G: 9.5051
# Epoch [10/100], Step [50/143], Loss D_A: 0.1215, Loss D_B: 0.3037, Loss G: 6.9253
# Epoch [10/100], Step [60/143], Loss D_A: 0.1167, Loss D_B: 0.3025, Loss G: 7.9212
# Epoch [10/100], Step [70/143], Loss D_A: 0.1426, Loss D_B: 0.2124, Loss G: 5.2980
# Epoch [10/100], Step [80/143], Loss D_A: 0.2708, Loss D_B: 0.2430, Loss G: 8.6062
# Epoch [10/100], Step [90/143], Loss D_A: 0.0735, Loss D_B: 0.2720, Loss G: 7.7664
# Epoch [10/100], Step [100/143], Loss D_A: 0.3498, Loss D_B: 0.2032, Loss G: 7.6575
# Epoch [10/100], Step [110/143], Loss D_A: 0.1186, Loss D_B: 0.1394, Loss G: 6.6860
# Epoch [10/100], Step [120/143], Loss D_A: 0.0514, Loss D_B: 0.2618, Loss G: 9.0759
# Epoch [10/100], Step [130/143], Loss D_A: 0.0847, Loss D_B: 0.1579, Loss G: 6.4584
# Epoch [10/100], Step [140/143], Loss D_A: 0.0707, Loss D_B: 0.1877, Loss G: 8.0434
# Epoch [11/100], Step [10/143], Loss D_A: 0.0583, Loss D_B: 0.2768, Loss G: 7.4586
# Epoch [11/100], Step [20/143], Loss D_A: 0.0717, Loss D_B: 0.2320, Loss G: 8.8789
# Epoch [11/100], Step [30/143], Loss D_A: 0.1019, Loss D_B: 0.0864, Loss G: 9.9692
# Epoch [11/100], Step [40/143], Loss D_A: 0.2713, Loss D_B: 0.2301, Loss G: 6.4770
# Epoch [11/100], Step [50/143], Loss D_A: 0.1776, Loss D_B: 0.1004, Loss G: 7.9916
# Epoch [11/100], Step [60/143], Loss D_A: 0.0902, Loss D_B: 0.0911, Loss G: 8.0334
# Epoch [11/100], Step [70/143], Loss D_A: 0.2574, Loss D_B: 0.1608, Loss G: 6.3443
# Epoch [11/100], Step [80/143], Loss D_A: 0.1572, Loss D_B: 0.3758, Loss G: 9.5331
# Epoch [11/100], Step [90/143], Loss D_A: 0.1135, Loss D_B: 0.2095, Loss G: 6.7004
# Epoch [11/100], Step [100/143], Loss D_A: 0.0802, Loss D_B: 0.1316, Loss G: 8.7701
# Epoch [11/100], Step [110/143], Loss D_A: 0.0875, Loss D_B: 0.1413, Loss G: 7.8928
# Epoch [11/100], Step [120/143], Loss D_A: 0.1065, Loss D_B: 0.0930, Loss G: 6.5485
# Epoch [11/100], Step [130/143], Loss D_A: 0.0904, Loss D_B: 0.1454, Loss G: 8.0388
# Epoch [11/100], Step [140/143], Loss D_A: 0.1594, Loss D_B: 0.0426, Loss G: 8.6848
# Epoch [12/100], Step [10/143], Loss D_A: 0.0947, Loss D_B: 0.1148, Loss G: 8.9478
# Epoch [12/100], Step [20/143], Loss D_A: 0.2942, Loss D_B: 0.0880, Loss G: 6.8352
# Epoch [12/100], Step [30/143], Loss D_A: 0.2054, Loss D_B: 0.2374, Loss G: 5.9207
# Epoch [12/100], Step [40/143], Loss D_A: 0.0653, Loss D_B: 0.2179, Loss G: 8.5924
# Epoch [12/100], Step [50/143], Loss D_A: 0.0976, Loss D_B: 0.0968, Loss G: 7.6525
# Epoch [12/100], Step [60/143], Loss D_A: 0.2362, Loss D_B: 0.0782, Loss G: 7.4119
# Epoch [12/100], Step [70/143], Loss D_A: 0.0953, Loss D_B: 0.1868, Loss G: 10.4005
# Epoch [12/100], Step [80/143], Loss D_A: 0.0852, Loss D_B: 0.1816, Loss G: 6.7036
# Epoch [12/100], Step [90/143], Loss D_A: 0.1183, Loss D_B: 0.1570, Loss G: 5.9971
# Epoch [12/100], Step [100/143], Loss D_A: 0.1133, Loss D_B: 0.2220, Loss G: 6.7553
# Epoch [12/100], Step [110/143], Loss D_A: 0.1431, Loss D_B: 0.2525, Loss G: 7.6239
# Epoch [12/100], Step [120/143], Loss D_A: 0.1441, Loss D_B: 0.1647, Loss G: 7.3666
# Epoch [12/100], Step [130/143], Loss D_A: 0.1541, Loss D_B: 0.1189, Loss G: 6.4233
# Epoch [12/100], Step [140/143], Loss D_A: 0.1305, Loss D_B: 0.0954, Loss G: 8.0210
# Epoch [13/100], Step [10/143], Loss D_A: 0.2217, Loss D_B: 0.2186, Loss G: 5.9248
# Epoch [13/100], Step [20/143], Loss D_A: 0.2095, Loss D_B: 0.0791, Loss G: 8.2759
# Epoch [13/100], Step [30/143], Loss D_A: 0.0380, Loss D_B: 0.0807, Loss G: 7.7124
# Epoch [13/100], Step [40/143], Loss D_A: 0.0558, Loss D_B: 0.0838, Loss G: 6.8981
# Epoch [13/100], Step [50/143], Loss D_A: 0.1273, Loss D_B: 0.1998, Loss G: 7.5521
# Epoch [13/100], Step [60/143], Loss D_A: 0.0772, Loss D_B: 0.3437, Loss G: 7.5284
# Epoch [13/100], Step [70/143], Loss D_A: 0.1996, Loss D_B: 0.1660, Loss G: 8.0879
# Epoch [13/100], Step [80/143], Loss D_A: 0.0437, Loss D_B: 0.0764, Loss G: 8.9710
# Epoch [13/100], Step [90/143], Loss D_A: 0.1997, Loss D_B: 0.0615, Loss G: 8.8133
# Epoch [13/100], Step [100/143], Loss D_A: 0.1190, Loss D_B: 0.0764, Loss G: 5.3466
# Epoch [13/100], Step [110/143], Loss D_A: 0.1590, Loss D_B: 0.0950, Loss G: 6.8526
# Epoch [13/100], Step [120/143], Loss D_A: 0.0785, Loss D_B: 0.4887, Loss G: 9.6119
# Epoch [13/100], Step [130/143], Loss D_A: 0.0734, Loss D_B: 0.0912, Loss G: 6.6122
# Epoch [13/100], Step [140/143], Loss D_A: 0.2581, Loss D_B: 0.2665, Loss G: 7.0678
# Epoch [14/100], Step [10/143], Loss D_A: 0.3473, Loss D_B: 0.2212, Loss G: 6.6783
# Epoch [14/100], Step [20/143], Loss D_A: 0.0458, Loss D_B: 0.0766, Loss G: 6.9896
# Epoch [14/100], Step [30/143], Loss D_A: 0.3366, Loss D_B: 0.2036, Loss G: 5.3750
# Epoch [14/100], Step [40/143], Loss D_A: 0.1134, Loss D_B: 0.2086, Loss G: 7.2832
# Epoch [14/100], Step [50/143], Loss D_A: 0.1440, Loss D_B: 0.1707, Loss G: 8.5990
# Epoch [14/100], Step [60/143], Loss D_A: 0.1895, Loss D_B: 0.2110, Loss G: 6.3693
# Epoch [14/100], Step [70/143], Loss D_A: 0.0647, Loss D_B: 0.1948, Loss G: 9.1792
# Epoch [14/100], Step [80/143], Loss D_A: 0.0931, Loss D_B: 0.2893, Loss G: 8.7930
# Epoch [14/100], Step [90/143], Loss D_A: 0.0575, Loss D_B: 0.2721, Loss G: 7.4251
# Epoch [14/100], Step [100/143], Loss D_A: 0.1995, Loss D_B: 0.1052, Loss G: 7.8679
# Epoch [14/100], Step [110/143], Loss D_A: 0.0649, Loss D_B: 0.0528, Loss G: 9.6859
# Epoch [14/100], Step [120/143], Loss D_A: 0.3414, Loss D_B: 0.2450, Loss G: 11.0333
# Epoch [14/100], Step [130/143], Loss D_A: 0.0709, Loss D_B: 0.0878, Loss G: 6.2793
# Epoch [14/100], Step [140/143], Loss D_A: 0.1560, Loss D_B: 0.1112, Loss G: 6.4839
# Epoch [15/100], Step [10/143], Loss D_A: 0.0617, Loss D_B: 0.1233, Loss G: 7.2211
# Epoch [15/100], Step [20/143], Loss D_A: 0.1558, Loss D_B: 0.1366, Loss G: 9.5110
# Epoch [15/100], Step [30/143], Loss D_A: 0.2789, Loss D_B: 0.2518, Loss G: 6.3310
# Epoch [15/100], Step [40/143], Loss D_A: 0.0851, Loss D_B: 0.1755, Loss G: 5.9789
# Epoch [15/100], Step [50/143], Loss D_A: 0.2245, Loss D_B: 0.1434, Loss G: 6.9748
# Epoch [15/100], Step [60/143], Loss D_A: 0.1173, Loss D_B: 0.1947, Loss G: 8.3519
# Epoch [15/100], Step [70/143], Loss D_A: 0.0697, Loss D_B: 0.1899, Loss G: 4.9841
# Epoch [15/100], Step [80/143], Loss D_A: 0.0844, Loss D_B: 0.1811, Loss G: 6.6645
# Epoch [15/100], Step [90/143], Loss D_A: 0.1270, Loss D_B: 0.1047, Loss G: 7.6484
# Epoch [15/100], Step [100/143], Loss D_A: 0.3258, Loss D_B: 0.0829, Loss G: 8.3801
# Epoch [15/100], Step [110/143], Loss D_A: 0.1378, Loss D_B: 0.1061, Loss G: 8.3281
# Epoch [15/100], Step [120/143], Loss D_A: 0.0529, Loss D_B: 0.1110, Loss G: 6.1450
# Epoch [15/100], Step [130/143], Loss D_A: 0.1017, Loss D_B: 0.0492, Loss G: 11.7822
# Epoch [15/100], Step [140/143], Loss D_A: 0.0919, Loss D_B: 0.0481, Loss G: 9.8853
# Epoch [16/100], Step [10/143], Loss D_A: 0.0550, Loss D_B: 0.0553, Loss G: 9.2951
# Epoch [16/100], Step [20/143], Loss D_A: 0.2470, Loss D_B: 0.1531, Loss G: 5.5218
# Epoch [16/100], Step [30/143], Loss D_A: 0.1102, Loss D_B: 0.1876, Loss G: 8.6175
# Epoch [16/100], Step [40/143], Loss D_A: 0.1589, Loss D_B: 0.2664, Loss G: 7.5706
# Epoch [16/100], Step [50/143], Loss D_A: 0.2463, Loss D_B: 0.3357, Loss G: 7.3379
# Epoch [16/100], Step [60/143], Loss D_A: 0.0547, Loss D_B: 0.0962, Loss G: 6.7494
# Epoch [16/100], Step [70/143], Loss D_A: 0.0730, Loss D_B: 0.0854, Loss G: 7.0046
# Epoch [16/100], Step [80/143], Loss D_A: 0.1659, Loss D_B: 0.1095, Loss G: 6.9161
# Epoch [16/100], Step [90/143], Loss D_A: 0.0597, Loss D_B: 0.1511, Loss G: 7.2655
# Epoch [16/100], Step [100/143], Loss D_A: 0.0530, Loss D_B: 0.0552, Loss G: 8.1070
# Epoch [16/100], Step [110/143], Loss D_A: 0.2131, Loss D_B: 0.2795, Loss G: 7.9870
# Epoch [16/100], Step [120/143], Loss D_A: 0.0340, Loss D_B: 0.2001, Loss G: 7.7321
# Epoch [16/100], Step [130/143], Loss D_A: 0.0949, Loss D_B: 0.0865, Loss G: 7.1375
# Epoch [16/100], Step [140/143], Loss D_A: 0.1290, Loss D_B: 0.0586, Loss G: 7.1783
# Epoch [17/100], Step [10/143], Loss D_A: 0.2233, Loss D_B: 0.0590, Loss G: 8.8051
# Epoch [17/100], Step [20/143], Loss D_A: 0.1356, Loss D_B: 0.0643, Loss G: 7.4058
# Epoch [17/100], Step [30/143], Loss D_A: 0.0547, Loss D_B: 0.1239, Loss G: 10.2719
# Epoch [17/100], Step [40/143], Loss D_A: 0.0234, Loss D_B: 0.0747, Loss G: 7.7770
# Epoch [17/100], Step [50/143], Loss D_A: 0.1067, Loss D_B: 0.1545, Loss G: 6.8733
# Epoch [17/100], Step [60/143], Loss D_A: 0.0588, Loss D_B: 0.1855, Loss G: 4.6496
# Epoch [17/100], Step [70/143], Loss D_A: 0.0730, Loss D_B: 0.1412, Loss G: 6.2717
# Epoch [17/100], Step [80/143], Loss D_A: 0.0864, Loss D_B: 0.0985, Loss G: 9.1321
# Epoch [17/100], Step [90/143], Loss D_A: 0.1646, Loss D_B: 0.1192, Loss G: 7.2363
# Epoch [17/100], Step [100/143], Loss D_A: 0.0661, Loss D_B: 0.2237, Loss G: 8.9421
# Epoch [17/100], Step [110/143], Loss D_A: 0.0528, Loss D_B: 0.2465, Loss G: 6.8264
# Epoch [17/100], Step [120/143], Loss D_A: 0.1407, Loss D_B: 0.1790, Loss G: 5.4976
# Epoch [17/100], Step [130/143], Loss D_A: 0.1707, Loss D_B: 0.1264, Loss G: 5.3120
# Epoch [17/100], Step [140/143], Loss D_A: 0.1454, Loss D_B: 0.1709, Loss G: 6.1951
# Epoch [18/100], Step [10/143], Loss D_A: 0.0675, Loss D_B: 0.1933, Loss G: 8.1563
# Epoch [18/100], Step [20/143], Loss D_A: 0.0804, Loss D_B: 0.0580, Loss G: 7.4660
# Epoch [18/100], Step [30/143], Loss D_A: 0.0387, Loss D_B: 0.0691, Loss G: 8.1691
# Epoch [18/100], Step [40/143], Loss D_A: 0.1509, Loss D_B: 0.1794, Loss G: 5.2633
# Epoch [18/100], Step [50/143], Loss D_A: 0.0422, Loss D_B: 0.1002, Loss G: 6.6197
# Epoch [18/100], Step [60/143], Loss D_A: 3.3516, Loss D_B: 0.1843, Loss G: 9.7196
# Epoch [18/100], Step [70/143], Loss D_A: 0.4474, Loss D_B: 0.1196, Loss G: 7.2350
# Epoch [18/100], Step [80/143], Loss D_A: 0.2865, Loss D_B: 0.0283, Loss G: 7.2264
# Epoch [18/100], Step [90/143], Loss D_A: 0.2686, Loss D_B: 0.1721, Loss G: 8.7204
# Epoch [18/100], Step [100/143], Loss D_A: 0.2625, Loss D_B: 0.0831, Loss G: 6.2246
# Epoch [18/100], Step [110/143], Loss D_A: 0.2548, Loss D_B: 0.1007, Loss G: 5.5432
# Epoch [18/100], Step [120/143], Loss D_A: 0.2742, Loss D_B: 0.1359, Loss G: 7.1972
# Epoch [18/100], Step [130/143], Loss D_A: 0.2491, Loss D_B: 0.1042, Loss G: 5.8406
# Epoch [18/100], Step [140/143], Loss D_A: 0.2593, Loss D_B: 0.3197, Loss G: 6.5259
# Epoch [19/100], Step [10/143], Loss D_A: 0.2414, Loss D_B: 0.1579, Loss G: 5.9630
# Epoch [19/100], Step [20/143], Loss D_A: 0.2465, Loss D_B: 0.1658, Loss G: 6.9260
# Epoch [19/100], Step [30/143], Loss D_A: 0.2388, Loss D_B: 0.0933, Loss G: 7.8469
# Epoch [19/100], Step [40/143], Loss D_A: 0.2630, Loss D_B: 0.2246, Loss G: 5.1540
# Epoch [19/100], Step [50/143], Loss D_A: 0.2519, Loss D_B: 0.2692, Loss G: 6.6862
# Epoch [19/100], Step [60/143], Loss D_A: 0.2261, Loss D_B: 0.1454, Loss G: 5.9808
# Epoch [19/100], Step [70/143], Loss D_A: 0.2256, Loss D_B: 0.1025, Loss G: 4.7610
# Epoch [19/100], Step [80/143], Loss D_A: 0.2506, Loss D_B: 0.2578, Loss G: 6.1911
# Epoch [19/100], Step [90/143], Loss D_A: 0.2318, Loss D_B: 0.1265, Loss G: 5.8953
# Epoch [19/100], Step [100/143], Loss D_A: 0.2534, Loss D_B: 0.6027, Loss G: 6.2208
# Epoch [19/100], Step [110/143], Loss D_A: 0.2613, Loss D_B: 0.1595, Loss G: 6.3566
# Epoch [19/100], Step [120/143], Loss D_A: 0.2619, Loss D_B: 0.0582, Loss G: 6.4975
# Epoch [19/100], Step [130/143], Loss D_A: 0.2609, Loss D_B: 0.1642, Loss G: 7.2462
# Epoch [19/100], Step [140/143], Loss D_A: 0.2630, Loss D_B: 0.2179, Loss G: 4.5514
# Epoch [20/100], Step [10/143], Loss D_A: 0.2454, Loss D_B: 0.1925, Loss G: 4.9257
# Epoch [20/100], Step [20/143], Loss D_A: 0.2633, Loss D_B: 0.1103, Loss G: 7.2363
# Epoch [20/100], Step [30/143], Loss D_A: 0.2521, Loss D_B: 0.2255, Loss G: 6.3212
# Epoch [20/100], Step [40/143], Loss D_A: 0.2147, Loss D_B: 0.3420, Loss G: 7.2789
# Epoch [20/100], Step [50/143], Loss D_A: 0.2413, Loss D_B: 0.3885, Loss G: 7.9517
# Epoch [20/100], Step [60/143], Loss D_A: 0.2579, Loss D_B: 0.1319, Loss G: 6.8854
# Epoch [20/100], Step [70/143], Loss D_A: 0.2412, Loss D_B: 0.2190, Loss G: 6.9772
# Epoch [20/100], Step [80/143], Loss D_A: 0.2430, Loss D_B: 0.1244, Loss G: 8.1179
# Epoch [20/100], Step [90/143], Loss D_A: 0.2121, Loss D_B: 0.1359, Loss G: 10.0950
# Epoch [20/100], Step [100/143], Loss D_A: 0.2352, Loss D_B: 0.1225, Loss G: 6.2101
# Epoch [20/100], Step [110/143], Loss D_A: 0.2639, Loss D_B: 0.1909, Loss G: 5.4540
# Epoch [20/100], Step [120/143], Loss D_A: 0.2668, Loss D_B: 0.1989, Loss G: 13.1651
# Epoch [20/100], Step [130/143], Loss D_A: 0.2160, Loss D_B: 0.1498, Loss G: 5.1277
# Epoch [20/100], Step [140/143], Loss D_A: 0.2767, Loss D_B: 0.2213, Loss G: 7.4928
# Epoch [21/100], Step [10/143], Loss D_A: 0.1999, Loss D_B: 0.0729, Loss G: 6.4121
# Epoch [21/100], Step [20/143], Loss D_A: 0.2583, Loss D_B: 0.1382, Loss G: 5.1434
# Epoch [21/100], Step [30/143], Loss D_A: 0.2650, Loss D_B: 0.1496, Loss G: 7.2792
# Epoch [21/100], Step [40/143], Loss D_A: 0.2500, Loss D_B: 0.2044, Loss G: 6.2918
# Epoch [21/100], Step [50/143], Loss D_A: 0.2430, Loss D_B: 0.1382, Loss G: 6.5030
# Epoch [21/100], Step [60/143], Loss D_A: 0.2535, Loss D_B: 0.1353, Loss G: 5.9517
# Epoch [21/100], Step [70/143], Loss D_A: 0.2224, Loss D_B: 0.1626, Loss G: 6.5347
# Epoch [21/100], Step [80/143], Loss D_A: 0.2258, Loss D_B: 0.1071, Loss G: 8.7998
# Epoch [21/100], Step [90/143], Loss D_A: 0.2063, Loss D_B: 0.1179, Loss G: 6.2426
# Epoch [21/100], Step [100/143], Loss D_A: 0.2063, Loss D_B: 0.0510, Loss G: 6.1855
# Epoch [21/100], Step [110/143], Loss D_A: 0.2120, Loss D_B: 0.0974, Loss G: 6.6732
# Epoch [21/100], Step [120/143], Loss D_A: 0.2506, Loss D_B: 0.1381, Loss G: 6.1681
# Epoch [21/100], Step [130/143], Loss D_A: 0.2553, Loss D_B: 0.1298, Loss G: 8.1177
# Epoch [21/100], Step [140/143], Loss D_A: 0.2312, Loss D_B: 0.0953, Loss G: 8.6870
# Epoch [22/100], Step [10/143], Loss D_A: 0.2097, Loss D_B: 0.1114, Loss G: 6.2875
# Epoch [22/100], Step [20/143], Loss D_A: 0.1990, Loss D_B: 0.1356, Loss G: 4.5589
# Epoch [22/100], Step [30/143], Loss D_A: 0.2383, Loss D_B: 0.1448, Loss G: 6.0960
# Epoch [22/100], Step [40/143], Loss D_A: 0.2828, Loss D_B: 0.1690, Loss G: 5.1923
# Epoch [22/100], Step [50/143], Loss D_A: 0.2086, Loss D_B: 0.3034, Loss G: 6.3060
# Epoch [22/100], Step [60/143], Loss D_A: 0.2092, Loss D_B: 0.0479, Loss G: 7.8063
# Epoch [22/100], Step [70/143], Loss D_A: 0.1906, Loss D_B: 0.0969, Loss G: 4.6882
# Epoch [22/100], Step [80/143], Loss D_A: 0.2155, Loss D_B: 0.0707, Loss G: 6.3931
# Epoch [22/100], Step [90/143], Loss D_A: 0.2736, Loss D_B: 0.0908, Loss G: 7.1580
# Epoch [22/100], Step [100/143], Loss D_A: 0.2954, Loss D_B: 0.1746, Loss G: 5.6927
# Epoch [22/100], Step [110/143], Loss D_A: 0.2086, Loss D_B: 0.1384, Loss G: 5.5133
# Epoch [22/100], Step [120/143], Loss D_A: 0.2272, Loss D_B: 0.1804, Loss G: 6.3557
# Epoch [22/100], Step [130/143], Loss D_A: 0.2544, Loss D_B: 0.1666, Loss G: 5.8855
# Epoch [22/100], Step [140/143], Loss D_A: 0.1650, Loss D_B: 0.0880, Loss G: 5.8766
# Epoch [23/100], Step [10/143], Loss D_A: 0.2001, Loss D_B: 0.2871, Loss G: 5.4160
# Epoch [23/100], Step [20/143], Loss D_A: 0.2434, Loss D_B: 0.2036, Loss G: 6.8520
# Epoch [23/100], Step [30/143], Loss D_A: 0.1875, Loss D_B: 0.0834, Loss G: 6.6807
# Epoch [23/100], Step [40/143], Loss D_A: 0.2238, Loss D_B: 0.1066, Loss G: 6.0246
# Epoch [23/100], Step [50/143], Loss D_A: 0.2053, Loss D_B: 0.0673, Loss G: 7.9092
# Epoch [23/100], Step [60/143], Loss D_A: 0.2925, Loss D_B: 0.2548, Loss G: 6.6443
# Epoch [23/100], Step [70/143], Loss D_A: 0.2613, Loss D_B: 0.3232, Loss G: 8.5843
# Epoch [23/100], Step [80/143], Loss D_A: 0.1558, Loss D_B: 0.0821, Loss G: 5.9535
# Epoch [23/100], Step [90/143], Loss D_A: 0.2472, Loss D_B: 0.2426, Loss G: 7.1883
# Epoch [23/100], Step [100/143], Loss D_A: 0.2266, Loss D_B: 0.1907, Loss G: 4.8890
# Epoch [23/100], Step [110/143], Loss D_A: 0.2477, Loss D_B: 0.1621, Loss G: 4.6407
# Epoch [23/100], Step [120/143], Loss D_A: 0.2083, Loss D_B: 0.2200, Loss G: 5.3697
# Epoch [23/100], Step [130/143], Loss D_A: 0.2552, Loss D_B: 0.1897, Loss G: 5.0554
# Epoch [23/100], Step [140/143], Loss D_A: 0.1524, Loss D_B: 0.0488, Loss G: 6.2426
# Epoch [24/100], Step [10/143], Loss D_A: 0.1878, Loss D_B: 0.3076, Loss G: 5.4141
# Epoch [24/100], Step [20/143], Loss D_A: 0.1263, Loss D_B: 0.0663, Loss G: 6.6450
# Epoch [24/100], Step [30/143], Loss D_A: 0.1725, Loss D_B: 0.0532, Loss G: 7.1657
# Epoch [24/100], Step [40/143], Loss D_A: 0.2083, Loss D_B: 0.1735, Loss G: 5.6028
# Epoch [24/100], Step [50/143], Loss D_A: 0.2350, Loss D_B: 0.0856, Loss G: 6.1617
# Epoch [24/100], Step [60/143], Loss D_A: 0.1837, Loss D_B: 0.0987, Loss G: 8.0386
# Epoch [24/100], Step [70/143], Loss D_A: 0.2582, Loss D_B: 0.1520, Loss G: 5.9412
# Epoch [24/100], Step [80/143], Loss D_A: 0.1947, Loss D_B: 0.0728, Loss G: 6.0296
# Epoch [24/100], Step [90/143], Loss D_A: 0.1757, Loss D_B: 0.1595, Loss G: 5.6864
# Epoch [24/100], Step [100/143], Loss D_A: 0.1621, Loss D_B: 0.0552, Loss G: 5.5828
# Epoch [24/100], Step [110/143], Loss D_A: 0.2024, Loss D_B: 0.1975, Loss G: 4.9776
# Epoch [24/100], Step [120/143], Loss D_A: 0.2093, Loss D_B: 0.1743, Loss G: 6.8144
# Epoch [24/100], Step [130/143], Loss D_A: 0.2985, Loss D_B: 0.1227, Loss G: 5.5314
# Epoch [24/100], Step [140/143], Loss D_A: 0.1551, Loss D_B: 0.1731, Loss G: 5.1934
# Epoch [25/100], Step [10/143], Loss D_A: 0.1682, Loss D_B: 0.1048, Loss G: 5.7124
# Epoch [25/100], Step [20/143], Loss D_A: 0.2773, Loss D_B: 0.2045, Loss G: 5.5229
# Epoch [25/100], Step [30/143], Loss D_A: 0.1550, Loss D_B: 0.1799, Loss G: 5.9117
# Epoch [25/100], Step [40/143], Loss D_A: 0.2633, Loss D_B: 0.1455, Loss G: 6.0692
# Epoch [25/100], Step [50/143], Loss D_A: 0.1684, Loss D_B: 0.1107, Loss G: 7.3807
# Epoch [25/100], Step [60/143], Loss D_A: 0.1958, Loss D_B: 0.0753, Loss G: 7.5897
# Epoch [25/100], Step [70/143], Loss D_A: 0.2194, Loss D_B: 0.2352, Loss G: 7.6513
# Epoch [25/100], Step [80/143], Loss D_A: 0.2426, Loss D_B: 0.2280, Loss G: 6.6760
# Epoch [25/100], Step [90/143], Loss D_A: 0.1543, Loss D_B: 0.1865, Loss G: 6.6752
# Epoch [25/100], Step [100/143], Loss D_A: 0.1490, Loss D_B: 0.2923, Loss G: 5.1182
# Epoch [25/100], Step [110/143], Loss D_A: 0.0903, Loss D_B: 0.0893, Loss G: 5.2747
# Epoch [25/100], Step [120/143], Loss D_A: 0.1557, Loss D_B: 0.2560, Loss G: 6.3302
# Epoch [25/100], Step [130/143], Loss D_A: 0.1858, Loss D_B: 0.2956, Loss G: 5.5653
# Epoch [25/100], Step [140/143], Loss D_A: 0.1123, Loss D_B: 0.1399, Loss G: 6.3927
# Epoch [26/100], Step [10/143], Loss D_A: 0.1521, Loss D_B: 0.0562, Loss G: 5.8154
# Epoch [26/100], Step [20/143], Loss D_A: 0.2132, Loss D_B: 0.3056, Loss G: 7.9061
# Epoch [26/100], Step [30/143], Loss D_A: 0.1512, Loss D_B: 0.2466, Loss G: 7.3955
# Epoch [26/100], Step [40/143], Loss D_A: 0.1811, Loss D_B: 0.2543, Loss G: 7.8722
# Epoch [26/100], Step [50/143], Loss D_A: 0.1869, Loss D_B: 0.1419, Loss G: 6.6580
# Epoch [26/100], Step [60/143], Loss D_A: 0.6061, Loss D_B: 0.1907, Loss G: 7.0464
# Epoch [26/100], Step [70/143], Loss D_A: 0.1284, Loss D_B: 0.1205, Loss G: 7.1793
# Epoch [26/100], Step [80/143], Loss D_A: 0.3168, Loss D_B: 0.1670, Loss G: 6.3316
# Epoch [26/100], Step [90/143], Loss D_A: 0.2720, Loss D_B: 0.0896, Loss G: 4.7109
# Epoch [26/100], Step [100/143], Loss D_A: 0.0916, Loss D_B: 0.0916, Loss G: 6.9507
# Epoch [26/100], Step [110/143], Loss D_A: 0.1512, Loss D_B: 0.1122, Loss G: 5.7408
# Epoch [26/100], Step [120/143], Loss D_A: 0.1789, Loss D_B: 0.1501, Loss G: 6.9281
# Epoch [26/100], Step [130/143], Loss D_A: 0.2229, Loss D_B: 0.1349, Loss G: 6.5745
# Epoch [26/100], Step [140/143], Loss D_A: 0.2427, Loss D_B: 0.1494, Loss G: 6.4936
# Epoch [27/100], Step [10/143], Loss D_A: 0.1002, Loss D_B: 0.0642, Loss G: 5.8722
# Epoch [27/100], Step [20/143], Loss D_A: 0.1854, Loss D_B: 0.1543, Loss G: 6.3983
# Epoch [27/100], Step [30/143], Loss D_A: 0.2263, Loss D_B: 0.1180, Loss G: 6.9502
# Epoch [27/100], Step [40/143], Loss D_A: 0.2443, Loss D_B: 0.0829, Loss G: 5.8939
# Epoch [27/100], Step [50/143], Loss D_A: 0.0985, Loss D_B: 0.0953, Loss G: 7.5699
# Epoch [27/100], Step [60/143], Loss D_A: 0.2102, Loss D_B: 0.1356, Loss G: 6.3157
# Epoch [27/100], Step [70/143], Loss D_A: 0.1538, Loss D_B: 0.1456, Loss G: 6.2886
# Epoch [27/100], Step [80/143], Loss D_A: 0.2945, Loss D_B: 0.1405, Loss G: 5.4288
# Epoch [27/100], Step [90/143], Loss D_A: 0.0948, Loss D_B: 0.1415, Loss G: 7.4887
# Epoch [27/100], Step [100/143], Loss D_A: 0.1454, Loss D_B: 0.0918, Loss G: 7.5334
# Epoch [27/100], Step [110/143], Loss D_A: 0.1049, Loss D_B: 0.1190, Loss G: 6.5861
# Epoch [27/100], Step [120/143], Loss D_A: 0.2394, Loss D_B: 0.1636, Loss G: 5.9411
# Epoch [27/100], Step [130/143], Loss D_A: 0.2859, Loss D_B: 0.3849, Loss G: 5.4794
# Epoch [27/100], Step [140/143], Loss D_A: 0.2176, Loss D_B: 0.1251, Loss G: 5.8637
# Epoch [28/100], Step [10/143], Loss D_A: 0.1198, Loss D_B: 0.1351, Loss G: 7.3767
# Epoch [28/100], Step [20/143], Loss D_A: 0.0576, Loss D_B: 0.0947, Loss G: 5.7827
# Epoch [28/100], Step [30/143], Loss D_A: 0.0892, Loss D_B: 0.0620, Loss G: 8.9846
# Epoch [28/100], Step [40/143], Loss D_A: 0.1815, Loss D_B: 0.1953, Loss G: 10.4379
# Epoch [28/100], Step [50/143], Loss D_A: 0.0956, Loss D_B: 0.2990, Loss G: 6.8023
# Epoch [28/100], Step [60/143], Loss D_A: 0.0458, Loss D_B: 0.1005, Loss G: 7.4732
# Epoch [28/100], Step [70/143], Loss D_A: 0.1972, Loss D_B: 0.1924, Loss G: 6.4466
# Epoch [28/100], Step [80/143], Loss D_A: 0.1162, Loss D_B: 0.3009, Loss G: 6.4190
# Epoch [28/100], Step [90/143], Loss D_A: 0.0560, Loss D_B: 0.1376, Loss G: 6.5744
# Epoch [28/100], Step [100/143], Loss D_A: 0.1348, Loss D_B: 0.1412, Loss G: 4.6891
# Epoch [28/100], Step [110/143], Loss D_A: 0.2230, Loss D_B: 0.2310, Loss G: 5.7669
# Epoch [28/100], Step [120/143], Loss D_A: 0.0872, Loss D_B: 0.1352, Loss G: 5.9651
# Epoch [28/100], Step [130/143], Loss D_A: 0.2375, Loss D_B: 0.0827, Loss G: 7.3917
# Epoch [28/100], Step [140/143], Loss D_A: 0.3728, Loss D_B: 0.0854, Loss G: 5.8208
# Epoch [29/100], Step [10/143], Loss D_A: 0.1471, Loss D_B: 0.2819, Loss G: 5.4303
# Epoch [29/100], Step [20/143], Loss D_A: 0.1406, Loss D_B: 0.2401, Loss G: 7.9719
# Epoch [29/100], Step [30/143], Loss D_A: 0.0658, Loss D_B: 0.2010, Loss G: 7.7499
# Epoch [29/100], Step [40/143], Loss D_A: 0.1723, Loss D_B: 0.0864, Loss G: 7.4573
# Epoch [29/100], Step [50/143], Loss D_A: 0.0535, Loss D_B: 0.0661, Loss G: 6.0770
# Epoch [29/100], Step [60/143], Loss D_A: 0.0770, Loss D_B: 0.1257, Loss G: 6.7840
# Epoch [29/100], Step [70/143], Loss D_A: 0.2431, Loss D_B: 0.0502, Loss G: 6.7983
# Epoch [29/100], Step [80/143], Loss D_A: 0.0859, Loss D_B: 0.1439, Loss G: 9.2140
# Epoch [29/100], Step [90/143], Loss D_A: 0.2043, Loss D_B: 0.1701, Loss G: 5.8742
# Epoch [29/100], Step [100/143], Loss D_A: 0.2552, Loss D_B: 0.1407, Loss G: 5.9705
# Epoch [29/100], Step [110/143], Loss D_A: 0.2308, Loss D_B: 0.2949, Loss G: 8.6725
# Epoch [29/100], Step [120/143], Loss D_A: 0.2974, Loss D_B: 0.2583, Loss G: 6.3640
# Epoch [29/100], Step [130/143], Loss D_A: 0.0964, Loss D_B: 0.0621, Loss G: 5.3760
# Epoch [29/100], Step [140/143], Loss D_A: 0.2323, Loss D_B: 0.1534, Loss G: 5.4189
# Epoch [30/100], Step [10/143], Loss D_A: 0.0706, Loss D_B: 0.1400, Loss G: 5.7148
# Epoch [30/100], Step [20/143], Loss D_A: 0.0464, Loss D_B: 0.1655, Loss G: 6.0774
# Epoch [30/100], Step [30/143], Loss D_A: 0.2006, Loss D_B: 0.1036, Loss G: 6.5123
# Epoch [30/100], Step [40/143], Loss D_A: 0.2212, Loss D_B: 0.0881, Loss G: 7.7652
# Epoch [30/100], Step [50/143], Loss D_A: 0.0999, Loss D_B: 0.2974, Loss G: 7.3781
# Epoch [30/100], Step [60/143], Loss D_A: 0.2300, Loss D_B: 0.0560, Loss G: 5.8858
# Epoch [30/100], Step [70/143], Loss D_A: 0.0648, Loss D_B: 0.1784, Loss G: 6.3994
# Epoch [30/100], Step [80/143], Loss D_A: 0.1325, Loss D_B: 0.4568, Loss G: 6.8440
# Epoch [30/100], Step [90/143], Loss D_A: 0.1545, Loss D_B: 0.1252, Loss G: 8.0128
# Epoch [30/100], Step [100/143], Loss D_A: 0.1544, Loss D_B: 0.1208, Loss G: 7.1402
# Epoch [30/100], Step [110/143], Loss D_A: 0.1403, Loss D_B: 0.2144, Loss G: 6.1581
# Epoch [30/100], Step [120/143], Loss D_A: 0.1030, Loss D_B: 0.1508, Loss G: 7.7258
# Epoch [30/100], Step [130/143], Loss D_A: 0.1671, Loss D_B: 0.1133, Loss G: 6.7170
# Epoch [30/100], Step [140/143], Loss D_A: 0.0799, Loss D_B: 0.0505, Loss G: 7.0875
# Epoch [31/100], Step [10/143], Loss D_A: 0.1267, Loss D_B: 0.0621, Loss G: 7.8593
# Epoch [31/100], Step [20/143], Loss D_A: 0.1427, Loss D_B: 0.0641, Loss G: 7.5038
# Epoch [31/100], Step [30/143], Loss D_A: 0.1556, Loss D_B: 0.2192, Loss G: 7.9512
# Epoch [31/100], Step [40/143], Loss D_A: 0.1770, Loss D_B: 0.1168, Loss G: 6.9079
# Epoch [31/100], Step [50/143], Loss D_A: 0.0446, Loss D_B: 0.1139, Loss G: 6.5398
# Epoch [31/100], Step [60/143], Loss D_A: 0.1500, Loss D_B: 0.1235, Loss G: 6.8940
# Epoch [31/100], Step [70/143], Loss D_A: 0.2479, Loss D_B: 0.0775, Loss G: 6.1417
# Epoch [31/100], Step [80/143], Loss D_A: 0.2445, Loss D_B: 0.1289, Loss G: 6.2052
# Epoch [31/100], Step [90/143], Loss D_A: 0.1381, Loss D_B: 0.0956, Loss G: 6.6277
# Epoch [31/100], Step [100/143], Loss D_A: 0.3217, Loss D_B: 0.1412, Loss G: 5.3685
# Epoch [31/100], Step [110/143], Loss D_A: 0.1744, Loss D_B: 0.1586, Loss G: 5.7451
# Epoch [31/100], Step [120/143], Loss D_A: 0.1761, Loss D_B: 0.0733, Loss G: 7.0658
# Epoch [31/100], Step [130/143], Loss D_A: 0.3804, Loss D_B: 0.0817, Loss G: 6.1367
# Epoch [31/100], Step [140/143], Loss D_A: 0.0471, Loss D_B: 0.1343, Loss G: 8.4314
# Epoch [32/100], Step [10/143], Loss D_A: 0.1611, Loss D_B: 0.0585, Loss G: 7.0896
# Epoch [32/100], Step [20/143], Loss D_A: 0.3726, Loss D_B: 0.0367, Loss G: 7.6986
# Epoch [32/100], Step [30/143], Loss D_A: 0.0872, Loss D_B: 0.1669, Loss G: 6.5297
# Epoch [32/100], Step [40/143], Loss D_A: 0.0974, Loss D_B: 0.1064, Loss G: 6.1912
# Epoch [32/100], Step [50/143], Loss D_A: 0.1796, Loss D_B: 0.1049, Loss G: 6.5603
# Epoch [32/100], Step [60/143], Loss D_A: 0.0882, Loss D_B: 0.1245, Loss G: 6.1414
# Epoch [32/100], Step [70/143], Loss D_A: 0.0553, Loss D_B: 0.1472, Loss G: 5.6459
# Epoch [32/100], Step [80/143], Loss D_A: 0.1551, Loss D_B: 0.0581, Loss G: 7.2912
# Epoch [32/100], Step [90/143], Loss D_A: 0.1028, Loss D_B: 0.1376, Loss G: 6.0689
# Epoch [32/100], Step [100/143], Loss D_A: 0.1144, Loss D_B: 0.2884, Loss G: 7.2956
# Epoch [32/100], Step [110/143], Loss D_A: 0.1380, Loss D_B: 0.1526, Loss G: 5.5800
# Epoch [32/100], Step [120/143], Loss D_A: 0.1586, Loss D_B: 0.1783, Loss G: 6.3837
# Epoch [32/100], Step [130/143], Loss D_A: 0.2115, Loss D_B: 0.0599, Loss G: 6.2644
# Epoch [32/100], Step [140/143], Loss D_A: 0.0818, Loss D_B: 0.0823, Loss G: 5.8081
# Epoch [33/100], Step [10/143], Loss D_A: 0.1645, Loss D_B: 0.0956, Loss G: 7.0137
# Epoch [33/100], Step [20/143], Loss D_A: 0.0444, Loss D_B: 0.1681, Loss G: 6.9793
# Epoch [33/100], Step [30/143], Loss D_A: 0.1364, Loss D_B: 0.1193, Loss G: 6.3920
# Epoch [33/100], Step [40/143], Loss D_A: 0.0966, Loss D_B: 0.1398, Loss G: 5.6030
# Epoch [33/100], Step [50/143], Loss D_A: 0.0935, Loss D_B: 0.1923, Loss G: 7.5437
# Epoch [33/100], Step [60/143], Loss D_A: 0.1605, Loss D_B: 0.1660, Loss G: 8.6566
# Epoch [33/100], Step [70/143], Loss D_A: 0.3350, Loss D_B: 0.1089, Loss G: 6.8133
# Epoch [33/100], Step [80/143], Loss D_A: 0.0514, Loss D_B: 0.0494, Loss G: 8.8674
# Epoch [33/100], Step [90/143], Loss D_A: 0.0939, Loss D_B: 0.1685, Loss G: 12.6883
# Epoch [33/100], Step [100/143], Loss D_A: 0.0944, Loss D_B: 0.0713, Loss G: 7.5320
# Epoch [33/100], Step [110/143], Loss D_A: 0.0979, Loss D_B: 0.1893, Loss G: 6.8458
# Epoch [33/100], Step [120/143], Loss D_A: 0.1149, Loss D_B: 0.0342, Loss G: 7.0141
# Epoch [33/100], Step [130/143], Loss D_A: 0.1314, Loss D_B: 0.1602, Loss G: 6.7778
# Epoch [33/100], Step [140/143], Loss D_A: 0.0866, Loss D_B: 0.0674, Loss G: 7.6642
# Epoch [34/100], Step [10/143], Loss D_A: 0.1403, Loss D_B: 0.0642, Loss G: 7.8217
# Epoch [34/100], Step [20/143], Loss D_A: 0.0222, Loss D_B: 0.0395, Loss G: 7.5163
# Epoch [34/100], Step [30/143], Loss D_A: 0.0833, Loss D_B: 0.1812, Loss G: 6.8299
# Epoch [34/100], Step [40/143], Loss D_A: 0.0947, Loss D_B: 0.1656, Loss G: 6.8397
# Epoch [34/100], Step [50/143], Loss D_A: 0.1670, Loss D_B: 0.1020, Loss G: 6.2091
# Epoch [34/100], Step [60/143], Loss D_A: 0.0472, Loss D_B: 0.1248, Loss G: 6.0344
# Epoch [34/100], Step [70/143], Loss D_A: 0.1596, Loss D_B: 0.1996, Loss G: 7.3016
# Epoch [34/100], Step [80/143], Loss D_A: 0.1990, Loss D_B: 0.1918, Loss G: 6.3400
# Epoch [34/100], Step [90/143], Loss D_A: 0.0861, Loss D_B: 0.0946, Loss G: 5.8848
# Epoch [34/100], Step [100/143], Loss D_A: 0.0752, Loss D_B: 0.1028, Loss G: 5.8655
# Epoch [34/100], Step [110/143], Loss D_A: 0.0363, Loss D_B: 0.1817, Loss G: 8.5802
# Epoch [34/100], Step [120/143], Loss D_A: 0.1282, Loss D_B: 0.1363, Loss G: 7.1266
# Epoch [34/100], Step [130/143], Loss D_A: 0.2830, Loss D_B: 0.1566, Loss G: 6.6314
# Epoch [34/100], Step [140/143], Loss D_A: 0.2567, Loss D_B: 0.0991, Loss G: 5.2278
# Epoch [35/100], Step [10/143], Loss D_A: 0.1391, Loss D_B: 0.0916, Loss G: 5.8661
# Epoch [35/100], Step [20/143], Loss D_A: 0.0906, Loss D_B: 0.0557, Loss G: 6.0101
# Epoch [35/100], Step [30/143], Loss D_A: 0.0442, Loss D_B: 0.1972, Loss G: 7.1052
# Epoch [35/100], Step [40/143], Loss D_A: 0.5256, Loss D_B: 0.0613, Loss G: 4.9643
# Epoch [35/100], Step [50/143], Loss D_A: 0.1100, Loss D_B: 0.1076, Loss G: 5.8437
# Epoch [35/100], Step [60/143], Loss D_A: 0.0771, Loss D_B: 0.0533, Loss G: 5.5823
# Epoch [35/100], Step [70/143], Loss D_A: 0.0620, Loss D_B: 0.1108, Loss G: 6.3499
# Epoch [35/100], Step [80/143], Loss D_A: 0.0447, Loss D_B: 0.0968, Loss G: 8.2393
# Epoch [35/100], Step [90/143], Loss D_A: 0.0354, Loss D_B: 0.1755, Loss G: 6.4238
# Epoch [35/100], Step [100/143], Loss D_A: 0.0937, Loss D_B: 0.1529, Loss G: 5.2964
# Epoch [35/100], Step [110/143], Loss D_A: 0.0543, Loss D_B: 0.1207, Loss G: 7.4939
# Epoch [35/100], Step [120/143], Loss D_A: 0.1250, Loss D_B: 0.0887, Loss G: 6.8291
# Epoch [35/100], Step [130/143], Loss D_A: 0.0426, Loss D_B: 0.1004, Loss G: 7.7752
# Epoch [35/100], Step [140/143], Loss D_A: 0.1479, Loss D_B: 0.0709, Loss G: 6.7260
# Epoch [36/100], Step [10/143], Loss D_A: 0.1642, Loss D_B: 0.0990, Loss G: 5.7872
# Epoch [36/100], Step [20/143], Loss D_A: 0.3396, Loss D_B: 0.1683, Loss G: 6.2477
# Epoch [36/100], Step [30/143], Loss D_A: 0.1261, Loss D_B: 0.0639, Loss G: 5.3330
# Epoch [36/100], Step [40/143], Loss D_A: 0.0839, Loss D_B: 0.2828, Loss G: 6.4466
# Epoch [36/100], Step [50/143], Loss D_A: 0.1208, Loss D_B: 0.0785, Loss G: 6.5065
# Epoch [36/100], Step [60/143], Loss D_A: 0.3008, Loss D_B: 0.1859, Loss G: 8.7723
# Epoch [36/100], Step [70/143], Loss D_A: 0.0188, Loss D_B: 0.0479, Loss G: 7.5889
# Epoch [36/100], Step [80/143], Loss D_A: 0.1267, Loss D_B: 0.1048, Loss G: 6.2996
# Epoch [36/100], Step [90/143], Loss D_A: 0.0457, Loss D_B: 0.2155, Loss G: 7.3793
# Epoch [36/100], Step [100/143], Loss D_A: 0.1185, Loss D_B: 0.1041, Loss G: 5.2448
# Epoch [36/100], Step [110/143], Loss D_A: 0.1121, Loss D_B: 0.0813, Loss G: 8.5480
# Epoch [36/100], Step [120/143], Loss D_A: 0.0776, Loss D_B: 0.0850, Loss G: 7.2525
# Epoch [36/100], Step [130/143], Loss D_A: 0.0954, Loss D_B: 0.0524, Loss G: 7.3768
# Epoch [36/100], Step [140/143], Loss D_A: 0.1824, Loss D_B: 0.3018, Loss G: 6.7247
# Epoch [37/100], Step [10/143], Loss D_A: 0.0365, Loss D_B: 0.0987, Loss G: 8.0794
# Epoch [37/100], Step [20/143], Loss D_A: 0.0214, Loss D_B: 0.0688, Loss G: 6.4409
# Epoch [37/100], Step [30/143], Loss D_A: 0.0699, Loss D_B: 0.0535, Loss G: 6.2471
# Epoch [37/100], Step [40/143], Loss D_A: 0.0376, Loss D_B: 0.0827, Loss G: 7.7967
# Epoch [37/100], Step [50/143], Loss D_A: 0.0994, Loss D_B: 0.1466, Loss G: 6.3686
# Epoch [37/100], Step [60/143], Loss D_A: 0.0372, Loss D_B: 0.1115, Loss G: 5.9901
# Epoch [37/100], Step [70/143], Loss D_A: 0.1241, Loss D_B: 0.1341, Loss G: 6.5852
# Epoch [37/100], Step [80/143], Loss D_A: 0.1307, Loss D_B: 0.1024, Loss G: 6.6279
# Epoch [37/100], Step [90/143], Loss D_A: 0.0241, Loss D_B: 0.0808, Loss G: 6.4754
# Epoch [37/100], Step [100/143], Loss D_A: 0.0305, Loss D_B: 0.1534, Loss G: 5.9608
# Epoch [37/100], Step [110/143], Loss D_A: 0.1771, Loss D_B: 0.1380, Loss G: 6.1135
# Epoch [37/100], Step [120/143], Loss D_A: 0.0731, Loss D_B: 0.1606, Loss G: 7.8615
# Epoch [37/100], Step [130/143], Loss D_A: 0.0558, Loss D_B: 0.2170, Loss G: 7.1828
# Epoch [37/100], Step [140/143], Loss D_A: 0.2462, Loss D_B: 0.0924, Loss G: 5.6907
# Epoch [38/100], Step [10/143], Loss D_A: 0.1347, Loss D_B: 0.0475, Loss G: 8.3250
# Epoch [38/100], Step [20/143], Loss D_A: 0.1241, Loss D_B: 0.1179, Loss G: 7.0572
# Epoch [38/100], Step [30/143], Loss D_A: 0.1628, Loss D_B: 0.1011, Loss G: 5.5033
# Epoch [38/100], Step [40/143], Loss D_A: 0.0708, Loss D_B: 0.1482, Loss G: 6.0419
# Epoch [38/100], Step [50/143], Loss D_A: 0.0983, Loss D_B: 0.0841, Loss G: 6.1084
# Epoch [38/100], Step [60/143], Loss D_A: 0.0517, Loss D_B: 0.1791, Loss G: 5.8707
# Epoch [38/100], Step [70/143], Loss D_A: 0.1632, Loss D_B: 0.1900, Loss G: 6.6163
# Epoch [38/100], Step [80/143], Loss D_A: 0.1918, Loss D_B: 0.0616, Loss G: 6.1955
# Epoch [38/100], Step [90/143], Loss D_A: 0.1099, Loss D_B: 0.2236, Loss G: 9.6170
# Epoch [38/100], Step [100/143], Loss D_A: 0.1192, Loss D_B: 0.1327, Loss G: 7.9785
# Epoch [38/100], Step [110/143], Loss D_A: 0.1758, Loss D_B: 0.0683, Loss G: 5.4536
# Epoch [38/100], Step [120/143], Loss D_A: 0.0891, Loss D_B: 0.0559, Loss G: 6.5532
# Epoch [38/100], Step [130/143], Loss D_A: 0.2071, Loss D_B: 0.1271, Loss G: 7.4941
# Epoch [38/100], Step [140/143], Loss D_A: 0.0455, Loss D_B: 0.1078, Loss G: 6.0362
# Epoch [39/100], Step [10/143], Loss D_A: 0.1059, Loss D_B: 0.0904, Loss G: 5.9499
# Epoch [39/100], Step [20/143], Loss D_A: 0.1251, Loss D_B: 0.1201, Loss G: 6.7241
# Epoch [39/100], Step [30/143], Loss D_A: 0.2179, Loss D_B: 0.1944, Loss G: 5.7114
# Epoch [39/100], Step [40/143], Loss D_A: 0.1327, Loss D_B: 0.2514, Loss G: 5.9100
# Epoch [39/100], Step [50/143], Loss D_A: 0.1249, Loss D_B: 0.2057, Loss G: 6.2905
# Epoch [39/100], Step [60/143], Loss D_A: 0.0557, Loss D_B: 0.0669, Loss G: 7.0772
# Epoch [39/100], Step [70/143], Loss D_A: 0.1249, Loss D_B: 0.1243, Loss G: 6.0578
# Epoch [39/100], Step [80/143], Loss D_A: 0.4883, Loss D_B: 0.0810, Loss G: 8.2248
# Epoch [39/100], Step [90/143], Loss D_A: 0.1119, Loss D_B: 0.3542, Loss G: 8.5759
# Epoch [39/100], Step [100/143], Loss D_A: 0.1145, Loss D_B: 0.1488, Loss G: 6.7943
# Epoch [39/100], Step [110/143], Loss D_A: 0.0759, Loss D_B: 0.1709, Loss G: 5.3505
# Epoch [39/100], Step [120/143], Loss D_A: 0.0497, Loss D_B: 0.1226, Loss G: 10.1444
# Epoch [39/100], Step [130/143], Loss D_A: 0.0789, Loss D_B: 0.1632, Loss G: 6.7910
# Epoch [39/100], Step [140/143], Loss D_A: 0.1120, Loss D_B: 0.2129, Loss G: 6.4002
# Epoch [40/100], Step [10/143], Loss D_A: 0.0877, Loss D_B: 0.1045, Loss G: 7.1562
# Epoch [40/100], Step [20/143], Loss D_A: 0.0819, Loss D_B: 0.0562, Loss G: 6.7404
# Epoch [40/100], Step [30/143], Loss D_A: 0.0635, Loss D_B: 0.1431, Loss G: 5.1648
# Epoch [40/100], Step [40/143], Loss D_A: 0.0886, Loss D_B: 0.1535, Loss G: 6.3412
# Epoch [40/100], Step [50/143], Loss D_A: 0.0560, Loss D_B: 0.1360, Loss G: 7.3519
# Epoch [40/100], Step [60/143], Loss D_A: 0.0901, Loss D_B: 0.2535, Loss G: 5.5937
# Epoch [40/100], Step [70/143], Loss D_A: 0.1499, Loss D_B: 0.1028, Loss G: 6.6947
# Epoch [40/100], Step [80/143], Loss D_A: 0.1092, Loss D_B: 0.0961, Loss G: 6.3576
# Epoch [40/100], Step [90/143], Loss D_A: 0.1988, Loss D_B: 0.3517, Loss G: 4.9174
# Epoch [40/100], Step [100/143], Loss D_A: 0.1513, Loss D_B: 0.1220, Loss G: 6.0932
# Epoch [40/100], Step [110/143], Loss D_A: 0.0347, Loss D_B: 0.0995, Loss G: 6.7974
# Epoch [40/100], Step [120/143], Loss D_A: 0.1268, Loss D_B: 0.0976, Loss G: 5.6217
# Epoch [40/100], Step [130/143], Loss D_A: 0.0700, Loss D_B: 0.1435, Loss G: 5.9714
# Epoch [40/100], Step [140/143], Loss D_A: 0.1974, Loss D_B: 0.1619, Loss G: 6.5113
# Epoch [41/100], Step [10/143], Loss D_A: 0.1561, Loss D_B: 0.2325, Loss G: 5.5925
# Epoch [41/100], Step [20/143], Loss D_A: 0.0390, Loss D_B: 0.1215, Loss G: 4.8596
# Epoch [41/100], Step [30/143], Loss D_A: 0.1015, Loss D_B: 0.1623, Loss G: 6.8324
# Epoch [41/100], Step [40/143], Loss D_A: 0.0788, Loss D_B: 0.1477, Loss G: 6.2445
# Epoch [41/100], Step [50/143], Loss D_A: 0.1309, Loss D_B: 0.0436, Loss G: 9.3112
# Epoch [41/100], Step [60/143], Loss D_A: 0.0653, Loss D_B: 0.0834, Loss G: 7.7545
# Epoch [41/100], Step [70/143], Loss D_A: 0.1611, Loss D_B: 0.2208, Loss G: 5.4593
# Epoch [41/100], Step [80/143], Loss D_A: 0.1528, Loss D_B: 0.1185, Loss G: 6.2567
# Epoch [41/100], Step [90/143], Loss D_A: 0.0336, Loss D_B: 0.0624, Loss G: 8.4445
# Epoch [41/100], Step [100/143], Loss D_A: 0.3753, Loss D_B: 0.0644, Loss G: 7.2904
# Epoch [41/100], Step [110/143], Loss D_A: 0.0887, Loss D_B: 0.0499, Loss G: 6.9563
# Epoch [41/100], Step [120/143], Loss D_A: 0.0404, Loss D_B: 0.2050, Loss G: 6.5888
# Epoch [41/100], Step [130/143], Loss D_A: 0.2206, Loss D_B: 0.1400, Loss G: 6.2419
# Epoch [41/100], Step [140/143], Loss D_A: 0.1422, Loss D_B: 0.1552, Loss G: 7.0079
# Epoch [42/100], Step [10/143], Loss D_A: 0.0611, Loss D_B: 0.1668, Loss G: 7.5506
# Epoch [42/100], Step [20/143], Loss D_A: 0.0494, Loss D_B: 0.2862, Loss G: 7.8165
# Epoch [42/100], Step [30/143], Loss D_A: 0.0869, Loss D_B: 0.0652, Loss G: 7.3531
# Epoch [42/100], Step [40/143], Loss D_A: 0.0916, Loss D_B: 0.2209, Loss G: 5.0228
# Epoch [42/100], Step [50/143], Loss D_A: 0.2030, Loss D_B: 0.1438, Loss G: 7.2705
# Epoch [42/100], Step [60/143], Loss D_A: 0.0301, Loss D_B: 0.0985, Loss G: 6.7674
# Epoch [42/100], Step [70/143], Loss D_A: 0.0678, Loss D_B: 0.1956, Loss G: 9.1031
# Epoch [42/100], Step [80/143], Loss D_A: 0.1484, Loss D_B: 0.0830, Loss G: 7.2233
# Epoch [42/100], Step [90/143], Loss D_A: 0.3359, Loss D_B: 0.0884, Loss G: 6.7553
# Epoch [42/100], Step [100/143], Loss D_A: 0.1116, Loss D_B: 0.0342, Loss G: 8.9999
# ...
# Epoch [87/100], Step [30/143], Loss D_A: 0.0756, Loss D_B: 0.1304, Loss G: 5.6881
# Epoch [87/100], Step [40/143], Loss D_A: 0.2918, Loss D_B: 0.1401, Loss G: 6.1651
# Epoch [87/100], Step [50/143], Loss D_A: 0.0366, Loss D_B: 0.1178, Loss G: 5.8898
# Epoch [87/100], Step [60/143], Loss D_A: 0.1445, Loss D_B: 0.0810, Loss G: 4.9165
# Epoch [87/100], Step [70/143], Loss D_A: 0.0678, Loss D_B: 0.0723, Loss G: 6.8602
# Epoch [87/100], Step [80/143], Loss D_A: 0.0532, Loss D_B: 0.0958, Loss G: 6.5640
# Epoch [87/100], Step [90/143], Loss D_A: 0.0241, Loss D_B: 0.1389, Loss G: 6.9221
# Epoch [87/100], Step [100/143], Loss D_A: 0.0848, Loss D_B: 0.0363, Loss G: 5.9044
# Epoch [87/100], Step [110/143], Loss D_A: 0.1078, Loss D_B: 0.1128, Loss G: 5.0952
# Epoch [87/100], Step [120/143], Loss D_A: 0.1307, Loss D_B: 0.1961, Loss G: 8.0841
# Epoch [87/100], Step [130/143], Loss D_A: 0.0387, Loss D_B: 0.0490, Loss G: 6.2559
# Epoch [87/100], Step [140/143], Loss D_A: 0.1387, Loss D_B: 0.1061, Loss G: 10.3675
# Epoch [88/100], Step [10/143], Loss D_A: 0.1374, Loss D_B: 0.0545, Loss G: 6.0113
# Epoch [88/100], Step [20/143], Loss D_A: 0.0300, Loss D_B: 0.0271, Loss G: 6.9602
# Epoch [88/100], Step [30/143], Loss D_A: 0.0656, Loss D_B: 0.1988, Loss G: 6.2702
# Epoch [88/100], Step [40/143], Loss D_A: 0.0737, Loss D_B: 0.0482, Loss G: 7.3231
# Epoch [88/100], Step [50/143], Loss D_A: 0.0311, Loss D_B: 0.0860, Loss G: 6.3510
# Epoch [88/100], Step [60/143], Loss D_A: 0.0933, Loss D_B: 0.0227, Loss G: 5.8245
# Epoch [88/100], Step [70/143], Loss D_A: 0.0736, Loss D_B: 0.0255, Loss G: 6.8343
# Epoch [88/100], Step [80/143], Loss D_A: 0.1238, Loss D_B: 0.0631, Loss G: 5.1359
# Epoch [88/100], Step [90/143], Loss D_A: 0.0849, Loss D_B: 0.0504, Loss G: 5.3184
# Epoch [88/100], Step [100/143], Loss D_A: 0.1355, Loss D_B: 0.0465, Loss G: 4.8630
# Epoch [88/100], Step [110/143], Loss D_A: 0.1311, Loss D_B: 0.0781, Loss G: 7.9566
# Epoch [88/100], Step [120/143], Loss D_A: 0.0223, Loss D_B: 0.0683, Loss G: 6.6510
# Epoch [88/100], Step [130/143], Loss D_A: 0.1057, Loss D_B: 0.0296, Loss G: 6.4546
# Epoch [88/100], Step [140/143], Loss D_A: 0.0395, Loss D_B: 0.0682, Loss G: 6.3087
# Epoch [89/100], Step [10/143], Loss D_A: 0.2246, Loss D_B: 0.0714, Loss G: 7.9943
# Epoch [89/100], Step [20/143], Loss D_A: 0.0502, Loss D_B: 0.0527, Loss G: 5.3408
# Epoch [89/100], Step [30/143], Loss D_A: 0.1128, Loss D_B: 0.0904, Loss G: 6.1409
# Epoch [89/100], Step [40/143], Loss D_A: 0.0809, Loss D_B: 0.0385, Loss G: 7.1118
# Epoch [89/100], Step [50/143], Loss D_A: 0.0580, Loss D_B: 0.0896, Loss G: 6.6938
# Epoch [89/100], Step [60/143], Loss D_A: 0.0944, Loss D_B: 0.0652, Loss G: 6.0831
# Epoch [89/100], Step [70/143], Loss D_A: 0.0584, Loss D_B: 0.0430, Loss G: 5.7714
# Epoch [89/100], Step [80/143], Loss D_A: 0.0355, Loss D_B: 0.0371, Loss G: 6.0023
# Epoch [89/100], Step [90/143], Loss D_A: 0.0384, Loss D_B: 0.0779, Loss G: 5.5052
# Epoch [89/100], Step [100/143], Loss D_A: 0.0384, Loss D_B: 0.0606, Loss G: 6.3014
# Epoch [89/100], Step [110/143], Loss D_A: 0.0491, Loss D_B: 0.1347, Loss G: 5.4962
# Epoch [89/100], Step [120/143], Loss D_A: 0.0747, Loss D_B: 0.0861, Loss G: 5.9515
# Epoch [89/100], Step [130/143], Loss D_A: 0.0457, Loss D_B: 0.0591, Loss G: 5.6943
# Epoch [89/100], Step [140/143], Loss D_A: 0.0836, Loss D_B: 0.0950, Loss G: 5.4678
# Epoch [90/100], Step [10/143], Loss D_A: 0.2358, Loss D_B: 0.1396, Loss G: 8.4318
# Epoch [90/100], Step [20/143], Loss D_A: 0.1538, Loss D_B: 0.0511, Loss G: 5.9370
# Epoch [90/100], Step [30/143], Loss D_A: 0.0755, Loss D_B: 0.2271, Loss G: 5.7573
# Epoch [90/100], Step [40/143], Loss D_A: 0.0645, Loss D_B: 0.0585, Loss G: 4.8848
# Epoch [90/100], Step [50/143], Loss D_A: 0.0198, Loss D_B: 0.1446, Loss G: 5.4763
# Epoch [90/100], Step [60/143], Loss D_A: 0.0348, Loss D_B: 0.0512, Loss G: 6.6630
# Epoch [90/100], Step [70/143], Loss D_A: 0.0816, Loss D_B: 0.0454, Loss G: 7.3238
# Epoch [90/100], Step [80/143], Loss D_A: 0.0382, Loss D_B: 0.0493, Loss G: 7.0908
# Epoch [90/100], Step [90/143], Loss D_A: 0.3279, Loss D_B: 0.0352, Loss G: 7.1934
# Epoch [90/100], Step [100/143], Loss D_A: 0.0819, Loss D_B: 0.1214, Loss G: 7.1244
# Epoch [90/100], Step [110/143], Loss D_A: 0.0410, Loss D_B: 0.0835, Loss G: 5.5723
# Epoch [90/100], Step [120/143], Loss D_A: 0.0809, Loss D_B: 0.0428, Loss G: 5.3099
# Epoch [90/100], Step [130/143], Loss D_A: 0.0758, Loss D_B: 0.0640, Loss G: 7.1319
# Epoch [90/100], Step [140/143], Loss D_A: 0.2311, Loss D_B: 0.1405, Loss G: 5.5407
# Epoch [91/100], Step [10/143], Loss D_A: 0.0476, Loss D_B: 0.1336, Loss G: 4.6481
# Epoch [91/100], Step [20/143], Loss D_A: 0.3550, Loss D_B: 0.1715, Loss G: 5.0582
# Epoch [91/100], Step [30/143], Loss D_A: 0.0521, Loss D_B: 0.0513, Loss G: 6.0262
# Epoch [91/100], Step [40/143], Loss D_A: 0.0850, Loss D_B: 0.0772, Loss G: 4.9230
# Epoch [91/100], Step [50/143], Loss D_A: 0.2131, Loss D_B: 0.0740, Loss G: 6.4841
# Epoch [91/100], Step [60/143], Loss D_A: 0.0471, Loss D_B: 0.0570, Loss G: 6.5234
# Epoch [91/100], Step [70/143], Loss D_A: 0.0721, Loss D_B: 0.0550, Loss G: 5.9254
# Epoch [91/100], Step [80/143], Loss D_A: 0.0361, Loss D_B: 0.0693, Loss G: 4.9950
# Epoch [91/100], Step [90/143], Loss D_A: 0.0378, Loss D_B: 0.0576, Loss G: 6.6031
# Epoch [91/100], Step [100/143], Loss D_A: 0.0462, Loss D_B: 0.0576, Loss G: 6.3820
# Epoch [91/100], Step [110/143], Loss D_A: 0.1384, Loss D_B: 0.1043, Loss G: 3.9842
# Epoch [91/100], Step [120/143], Loss D_A: 0.2082, Loss D_B: 0.0570, Loss G: 5.3402
# Epoch [91/100], Step [130/143], Loss D_A: 0.0391, Loss D_B: 0.0839, Loss G: 6.1524
# Epoch [91/100], Step [140/143], Loss D_A: 0.0641, Loss D_B: 0.0594, Loss G: 6.3546
# Epoch [92/100], Step [10/143], Loss D_A: 0.1737, Loss D_B: 0.0781, Loss G: 5.8082
# Epoch [92/100], Step [20/143], Loss D_A: 0.1995, Loss D_B: 0.1218, Loss G: 5.3053
# Epoch [92/100], Step [30/143], Loss D_A: 0.1456, Loss D_B: 0.0888, Loss G: 5.5595
# Epoch [92/100], Step [40/143], Loss D_A: 0.1667, Loss D_B: 0.0977, Loss G: 5.1818
# Epoch [92/100], Step [50/143], Loss D_A: 0.0676, Loss D_B: 0.1262, Loss G: 6.0123
# Epoch [92/100], Step [60/143], Loss D_A: 0.1248, Loss D_B: 0.0761, Loss G: 5.2860
# Epoch [92/100], Step [70/143], Loss D_A: 0.0622, Loss D_B: 0.0579, Loss G: 5.6751
# Epoch [92/100], Step [80/143], Loss D_A: 0.0309, Loss D_B: 0.0485, Loss G: 6.5476
# Epoch [92/100], Step [90/143], Loss D_A: 0.0475, Loss D_B: 0.0528, Loss G: 5.8858
# Epoch [92/100], Step [100/143], Loss D_A: 0.0173, Loss D_B: 0.0871, Loss G: 6.2195
# Epoch [92/100], Step [110/143], Loss D_A: 0.0343, Loss D_B: 0.0622, Loss G: 6.1882
# Epoch [92/100], Step [120/143], Loss D_A: 0.0438, Loss D_B: 0.0685, Loss G: 4.9748
# Epoch [92/100], Step [130/143], Loss D_A: 0.1493, Loss D_B: 0.0625, Loss G: 5.5230
# Epoch [92/100], Step [140/143], Loss D_A: 0.0400, Loss D_B: 0.1597, Loss G: 5.9394
# Epoch [93/100], Step [10/143], Loss D_A: 0.5016, Loss D_B: 0.0701, Loss G: 5.9337
# Epoch [93/100], Step [20/143], Loss D_A: 0.1231, Loss D_B: 0.1183, Loss G: 6.6486
# Epoch [93/100], Step [30/143], Loss D_A: 0.0723, Loss D_B: 0.0296, Loss G: 5.8860
# Epoch [93/100], Step [40/143], Loss D_A: 0.2919, Loss D_B: 0.0488, Loss G: 4.7621
# Epoch [93/100], Step [50/143], Loss D_A: 0.0466, Loss D_B: 0.0633, Loss G: 5.4419
# Epoch [93/100], Step [60/143], Loss D_A: 0.0930, Loss D_B: 0.0393, Loss G: 5.5543
# Epoch [93/100], Step [70/143], Loss D_A: 0.0588, Loss D_B: 0.0609, Loss G: 5.5338
# Epoch [93/100], Step [80/143], Loss D_A: 0.0976, Loss D_B: 0.1024, Loss G: 5.0306
# Epoch [93/100], Step [90/143], Loss D_A: 0.0961, Loss D_B: 0.0591, Loss G: 7.3978
# Epoch [93/100], Step [100/143], Loss D_A: 0.0589, Loss D_B: 0.0576, Loss G: 6.2951
# Epoch [93/100], Step [110/143], Loss D_A: 0.1956, Loss D_B: 0.1001, Loss G: 6.4228
# Epoch [93/100], Step [120/143], Loss D_A: 0.0563, Loss D_B: 0.0516, Loss G: 6.1802
# Epoch [93/100], Step [130/143], Loss D_A: 0.2312, Loss D_B: 0.0945, Loss G: 9.4483
# Epoch [93/100], Step [140/143], Loss D_A: 0.0430, Loss D_B: 0.0867, Loss G: 6.0682
# Epoch [94/100], Step [10/143], Loss D_A: 0.0992, Loss D_B: 0.0303, Loss G: 4.9038
# Epoch [94/100], Step [20/143], Loss D_A: 0.0211, Loss D_B: 0.0532, Loss G: 5.9151
# Epoch [94/100], Step [30/143], Loss D_A: 0.3397, Loss D_B: 0.0396, Loss G: 6.7975
# Epoch [94/100], Step [40/143], Loss D_A: 0.0473, Loss D_B: 0.0543, Loss G: 5.6714
# Epoch [94/100], Step [50/143], Loss D_A: 0.0452, Loss D_B: 0.1731, Loss G: 4.7155
# Epoch [94/100], Step [60/143], Loss D_A: 0.0299, Loss D_B: 0.1321, Loss G: 5.6556
# Epoch [94/100], Step [70/143], Loss D_A: 0.2310, Loss D_B: 0.0835, Loss G: 5.8278
# Epoch [94/100], Step [80/143], Loss D_A: 0.1279, Loss D_B: 0.0839, Loss G: 6.0047
# Epoch [94/100], Step [90/143], Loss D_A: 0.0844, Loss D_B: 0.0529, Loss G: 7.3877
# Epoch [94/100], Step [100/143], Loss D_A: 0.1357, Loss D_B: 0.1698, Loss G: 4.6860
# Epoch [94/100], Step [110/143], Loss D_A: 0.0705, Loss D_B: 0.0583, Loss G: 5.7869
# Epoch [94/100], Step [120/143], Loss D_A: 0.0799, Loss D_B: 0.1708, Loss G: 5.4445
# Epoch [94/100], Step [130/143], Loss D_A: 0.0487, Loss D_B: 0.0992, Loss G: 6.3047
# Epoch [94/100], Step [140/143], Loss D_A: 0.1035, Loss D_B: 0.0338, Loss G: 6.2586
# Epoch [95/100], Step [10/143], Loss D_A: 0.2006, Loss D_B: 0.0394, Loss G: 5.5839
# Epoch [95/100], Step [20/143], Loss D_A: 0.0671, Loss D_B: 0.1265, Loss G: 5.5048
# Epoch [95/100], Step [30/143], Loss D_A: 0.0528, Loss D_B: 0.0889, Loss G: 5.1132
# Epoch [95/100], Step [40/143], Loss D_A: 0.0573, Loss D_B: 0.1250, Loss G: 5.8865
# Epoch [95/100], Step [50/143], Loss D_A: 0.1372, Loss D_B: 0.1806, Loss G: 5.8174
# Epoch [95/100], Step [60/143], Loss D_A: 0.1368, Loss D_B: 0.0488, Loss G: 8.3181
# Epoch [95/100], Step [70/143], Loss D_A: 0.0601, Loss D_B: 0.0569, Loss G: 6.1194
# Epoch [95/100], Step [80/143], Loss D_A: 0.0563, Loss D_B: 0.0738, Loss G: 5.3377
# Epoch [95/100], Step [90/143], Loss D_A: 0.1200, Loss D_B: 0.0642, Loss G: 4.5165
# Epoch [95/100], Step [100/143], Loss D_A: 0.0676, Loss D_B: 0.0304, Loss G: 6.1615
# Epoch [95/100], Step [110/143], Loss D_A: 0.0626, Loss D_B: 0.1509, Loss G: 5.7092
# Epoch [95/100], Step [120/143], Loss D_A: 0.1500, Loss D_B: 0.0359, Loss G: 6.3600
# Epoch [95/100], Step [130/143], Loss D_A: 0.0693, Loss D_B: 0.0916, Loss G: 7.0655
# Epoch [95/100], Step [140/143], Loss D_A: 0.0997, Loss D_B: 0.0420, Loss G: 5.4176
# Epoch [96/100], Step [10/143], Loss D_A: 0.0937, Loss D_B: 0.0395, Loss G: 6.5243
# Epoch [96/100], Step [20/143], Loss D_A: 0.0703, Loss D_B: 0.0503, Loss G: 6.4153
# Epoch [96/100], Step [30/143], Loss D_A: 0.0414, Loss D_B: 0.1118, Loss G: 5.9367
# Epoch [96/100], Step [40/143], Loss D_A: 0.2062, Loss D_B: 0.0646, Loss G: 5.9208
# Epoch [96/100], Step [50/143], Loss D_A: 0.1203, Loss D_B: 0.1000, Loss G: 5.9245
# Epoch [96/100], Step [60/143], Loss D_A: 0.0526, Loss D_B: 0.0652, Loss G: 5.3103
# Epoch [96/100], Step [70/143], Loss D_A: 0.0605, Loss D_B: 0.0664, Loss G: 4.8538
# Epoch [96/100], Step [80/143], Loss D_A: 0.0576, Loss D_B: 0.0650, Loss G: 5.2111
# Epoch [96/100], Step [90/143], Loss D_A: 0.0436, Loss D_B: 0.0559, Loss G: 5.7722
# Epoch [96/100], Step [100/143], Loss D_A: 0.2318, Loss D_B: 0.0478, Loss G: 5.1237
# Epoch [96/100], Step [110/143], Loss D_A: 0.0618, Loss D_B: 0.0830, Loss G: 5.5233
# Epoch [96/100], Step [120/143], Loss D_A: 0.0558, Loss D_B: 0.0494, Loss G: 4.8561
# Epoch [96/100], Step [130/143], Loss D_A: 0.0765, Loss D_B: 0.2351, Loss G: 8.5809
# Epoch [96/100], Step [140/143], Loss D_A: 0.0424, Loss D_B: 0.0577, Loss G: 6.7626
# Epoch [97/100], Step [10/143], Loss D_A: 0.1887, Loss D_B: 0.0896, Loss G: 5.7377
# Epoch [97/100], Step [20/143], Loss D_A: 0.2093, Loss D_B: 0.0240, Loss G: 4.8510
# Epoch [97/100], Step [30/143], Loss D_A: 0.2503, Loss D_B: 0.0434, Loss G: 6.2620
# Epoch [97/100], Step [40/143], Loss D_A: 0.0601, Loss D_B: 0.0609, Loss G: 6.1121
# Epoch [97/100], Step [50/143], Loss D_A: 0.1798, Loss D_B: 0.0861, Loss G: 5.0345
# Epoch [97/100], Step [60/143], Loss D_A: 0.0495, Loss D_B: 0.0964, Loss G: 6.8154
# Epoch [97/100], Step [70/143], Loss D_A: 0.1123, Loss D_B: 0.0542, Loss G: 5.0908
# Epoch [97/100], Step [80/143], Loss D_A: 0.0672, Loss D_B: 0.0656, Loss G: 4.9814
# Epoch [97/100], Step [90/143], Loss D_A: 0.0989, Loss D_B: 0.0858, Loss G: 5.3794
# Epoch [97/100], Step [100/143], Loss D_A: 0.0455, Loss D_B: 0.0535, Loss G: 5.2463
# Epoch [97/100], Step [110/143], Loss D_A: 0.1323, Loss D_B: 0.0620, Loss G: 5.9758
# Epoch [97/100], Step [120/143], Loss D_A: 0.0666, Loss D_B: 0.0291, Loss G: 5.5220
# Epoch [97/100], Step [130/143], Loss D_A: 0.0672, Loss D_B: 0.0303, Loss G: 5.6384
# Epoch [97/100], Step [140/143], Loss D_A: 0.0696, Loss D_B: 0.0524, Loss G: 5.4936
# Epoch [98/100], Step [10/143], Loss D_A: 0.0428, Loss D_B: 0.0433, Loss G: 5.7993
# Epoch [98/100], Step [20/143], Loss D_A: 0.0477, Loss D_B: 0.1154, Loss G: 6.2434
# Epoch [98/100], Step [30/143], Loss D_A: 0.0662, Loss D_B: 0.0797, Loss G: 6.2215
# Epoch [98/100], Step [40/143], Loss D_A: 0.0250, Loss D_B: 0.0452, Loss G: 5.7708
# Epoch [98/100], Step [50/143], Loss D_A: 0.1188, Loss D_B: 0.0707, Loss G: 5.6132
# Epoch [98/100], Step [60/143], Loss D_A: 0.0496, Loss D_B: 0.0693, Loss G: 4.5675
# Epoch [98/100], Step [70/143], Loss D_A: 0.0782, Loss D_B: 0.1103, Loss G: 7.1497
# Epoch [98/100], Step [80/143], Loss D_A: 0.1529, Loss D_B: 0.0353, Loss G: 5.0388
# Epoch [98/100], Step [90/143], Loss D_A: 0.1858, Loss D_B: 0.0561, Loss G: 8.5760
# Epoch [98/100], Step [100/143], Loss D_A: 0.2868, Loss D_B: 0.0622, Loss G: 5.1302
# Epoch [98/100], Step [110/143], Loss D_A: 0.3122, Loss D_B: 0.0476, Loss G: 4.3588
# Epoch [98/100], Step [120/143], Loss D_A: 0.0322, Loss D_B: 0.0819, Loss G: 5.2434
# Epoch [98/100], Step [130/143], Loss D_A: 0.0563, Loss D_B: 0.0545, Loss G: 5.2027
# Epoch [98/100], Step [140/143], Loss D_A: 0.0995, Loss D_B: 0.0514, Loss G: 5.1222
# Epoch [99/100], Step [10/143], Loss D_A: 0.0837, Loss D_B: 0.0561, Loss G: 7.0062
# Epoch [99/100], Step [20/143], Loss D_A: 0.0447, Loss D_B: 0.0538, Loss G: 5.3709
# Epoch [99/100], Step [30/143], Loss D_A: 0.0613, Loss D_B: 0.0525, Loss G: 6.4581
# Epoch [99/100], Step [40/143], Loss D_A: 0.0861, Loss D_B: 0.0813, Loss G: 6.1106
# Epoch [99/100], Step [50/143], Loss D_A: 0.1526, Loss D_B: 0.0440, Loss G: 4.4699
# Epoch [99/100], Step [60/143], Loss D_A: 0.0541, Loss D_B: 0.0328, Loss G: 7.1071
# Epoch [99/100], Step [70/143], Loss D_A: 0.1546, Loss D_B: 0.0922, Loss G: 5.1733
# Epoch [99/100], Step [80/143], Loss D_A: 0.0739, Loss D_B: 0.0829, Loss G: 4.7087
# Epoch [99/100], Step [90/143], Loss D_A: 0.1878, Loss D_B: 0.0923, Loss G: 5.2755
# Epoch [99/100], Step [100/143], Loss D_A: 0.0673, Loss D_B: 0.0832, Loss G: 5.7216
# Epoch [99/100], Step [110/143], Loss D_A: 0.0710, Loss D_B: 0.0560, Loss G: 5.5695
# Epoch [99/100], Step [120/143], Loss D_A: 0.0194, Loss D_B: 0.1016, Loss G: 5.0082
# Epoch [99/100], Step [130/143], Loss D_A: 0.0725, Loss D_B: 0.1270, Loss G: 6.2200
# Epoch [99/100], Step [140/143], Loss D_A: 0.0591, Loss D_B: 0.1595, Loss G: 5.1431
# Epoch [100/100], Step [10/143], Loss D_A: 0.1067, Loss D_B: 0.1989, Loss G: 7.8986
# Epoch [100/100], Step [20/143], Loss D_A: 0.0545, Loss D_B: 0.1049, Loss G: 7.4620
# Epoch [100/100], Step [30/143], Loss D_A: 0.0991, Loss D_B: 0.0714, Loss G: 6.3813
# Epoch [100/100], Step [40/143], Loss D_A: 0.1434, Loss D_B: 0.0468, Loss G: 4.8695
# Epoch [100/100], Step [50/143], Loss D_A: 0.1760, Loss D_B: 0.0654, Loss G: 4.6152
# Epoch [100/100], Step [60/143], Loss D_A: 0.2050, Loss D_B: 0.0300, Loss G: 5.4246
# Epoch [100/100], Step [70/143], Loss D_A: 0.0444, Loss D_B: 0.0558, Loss G: 5.6224
# Epoch [100/100], Step [80/143], Loss D_A: 0.0470, Loss D_B: 0.0668, Loss G: 4.7020
# Epoch [100/100], Step [90/143], Loss D_A: 0.0947, Loss D_B: 0.0573, Loss G: 5.7515
# Epoch [100/100], Step [100/143], Loss D_A: 0.1907, Loss D_B: 0.1944, Loss G: 4.1272
# Epoch [100/100], Step [110/143], Loss D_A: 0.0972, Loss D_B: 0.0417, Loss G: 5.9751
# Epoch [100/100], Step [120/143], Loss D_A: 0.1797, Loss D_B: 0.0349, Loss G: 5.2076
# Epoch [100/100], Step [130/143], Loss D_A: 0.1212, Loss D_B: 0.0812, Loss G: 5.7615
# Epoch [100/100], Step [140/143], Loss D_A: 0.0384, Loss D_B: 0.0778, Loss G: 5.3762

# %% [markdown]
# ## 7. Visualização e Guarda dos Resultados e Modelos

# %% [markdown]
# ### 7.1 Modelos
# Após o término do treino, os modelos gerados foram guardados para utilização futura. Isto inclui os geradores e discriminadores, tanto no sentido A para B quanto no sentido B para A. Guardar os modelos permite que sejam carregados posteriormente para realizar inferências ou continuar o treino a partir do ponto onde parou.
#
# Os modelos foram guardados nos seguintes ficheiros:
# - Gerador A para B (`netG_A2B.pth`)
# - Gerador B para A (`netG_B2A.pth`)
# - Discriminador A (`netD_A.pth`)
# - Discriminador B (`netD_B.pth`)
#
# A diretoria para armazenar os modelos é `./saved_models`.
#
# O código utilizado para guardar os modelos é o seguinte:

# %%
# Diretoria para guardar os modelos
model_dir = './saved_models'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Guardar os modelos
torch.save(netG_A2B.state_dict(), os.path.join(model_dir, 'netG_A2B.pth'))
torch.save(netG_B2A.state_dict(), os.path.join(model_dir, 'netG_B2A.pth'))
torch.save(netD_A.state_dict(), os.path.join(model_dir, 'netD_A.pth'))
torch.save(netD_B.state_dict(), os.path.join(model_dir, 'netD_B.pth'))

print("Modelos guardados em:", model_dir)
# Out:
# Modelos guardados em: ./saved_models

# %% [markdown]
# ### 7.2 Gráficos de Perdas
#
# Os gráficos abaixo mostram a evolução das perdas do discriminador A (Loss D_A), do discriminador B (Loss D_B) e do gerador (Loss G) ao longo do treino.
#
# **Loss D_A (Smoothed)**:
# - Este gráfico mostra a perda do discriminador A ao longo do treino.
# - Observa-se uma diminuição geral da perda com algumas flutuações ao longo do tempo.
# - As flutuações são esperadas devido à natureza adversarial do treino GAN, onde o discriminador e o gerador se desafiam mutuamente.
#
# **Loss D_B (Smoothed)**:
# - Este gráfico mostra a perda do discriminador B.
# - Semelhante à perda do discriminador A, também apresenta uma tendência decrescente com flutuações.
# - A diminuição da perda sugere que o discriminador B está a melhorar na distinção entre imagens reais e geradas.
#
# **Loss G (Smoothed)**:
# - Este gráfico apresenta a perda do gerador.
# - Uma perda menor indica que o gerador está a melhorar na criação de imagens que são convincentes para os discriminadores.
# - Observa-se uma tendência geral de redução na perda, indicando melhorias no desempenho do gerador ao longo do treino.
#
# Os valores de perda foram suavizados usando uma média móvel para facilitar a visualização da tendência geral. Isto ajuda a reduzir o ruído e permite uma análise mais clara da performance dos modelos.
#
# #### Interpretação dos Resultados
#
# - **Diminuição Geral das Perdas**: A diminuição geral das perdas D_A e D_B sugere que os discriminadores estão a melhorar a sua capacidade de distinguir entre imagens reais e geradas.
# - **Melhoria do Gerador**: A perda do gerador (Loss G) mostra uma tendência decrescente, indicando que o gerador está a produzir imagens que se tornam progressivamente mais convincentes para os discriminadores.
# - **Flutuações**: As flutuações nas perdas são normais devido à natureza adversarial do treino GAN, onde os modelos estão constantemente a tentar superar-se mutuamente.
#
# Estes resultados indicam que o treino está a evoluir conforme esperado, com melhorias contínuas nos modelos tanto dos discriminadores quanto do gerador.

# %%
plot_losses(losses)

# %% [markdown]
# ### 7.3 Visualização das Imagens
# Para verificar a qualidade das imagens geradas pelo modelo, visualizámos algumas das imagens geradas. A função `visualize_random_results` foi utilizada para selecionar aleatoriamente 4 imagens do conjunto de dados, onde cada linha do gráfico mostra a imagem original do Pokémon e a imagem gerada com o estilo de Van Gogh.
#
# Esta abordagem permite uma verificação visual rápida da qualidade das imagens geradas e garante que os modelos estão a funcionar conforme esperado.
#
# A função para visualizar os resultados é a seguinte:

# %%
import random

def denormalize(tensor):
    return tensor * 0.5 + 0.5

def visualize_random_results(dataloader, netG_A2B, num_images=4):
    netG_A2B.eval()
    with torch.no_grad():
        all_batches = list(dataloader)
        random_batches = random.sample(all_batches, num_images // 2)  # Selecionar batches aleatórios
        fig, axs = plt.subplots(num_images // 2, 2, figsize=(10, 5 * (num_images // 2)))

        for i, batch in enumerate(random_batches):
            real_A = batch['A'].to(device)
            fake_B = netG_A2B(real_A)

            for j in range(2):  # Considerando que queremos mostrar 2 imagens por linha
                ax = axs[i][j] if num_images > 2 else axs[j]

                if j % 2 == 0:
                    ax.imshow(transforms.ToPILImage()(denormalize(real_A[j % len(real_A)]).cpu()))
                    ax.set_title('Original Pokémon')
                else:
                    ax.imshow(transforms.ToPILImage()(denormalize(fake_B[j % len(fake_B)]).cpu()))
                    ax.set_title('Estilo Van Gogh')

                ax.axis('off')

        plt.tight_layout()
        plt.show()

visualize_random_results(dataloader, netG_A2B, num_images=4)

# %% [markdown]
# Código para Guardar e visualizar os resultados de várias imagens.

# %%
def denormalize(tensor):
    return tensor * 0.5 + 0.5

def visualize_results(dataloader, netG_A2B, output_dir):
    netG_A2B.eval()
    with torch.no_grad():
        for i, batch in enumerate(dataloader):
            real_A = batch['A'].to(device)
            fake_B = netG_A2B(real_A)

            for j in range(len(real_A)):
                fig, ax = plt.subplots(1, 2, figsize=(10, 5))

                ax[0].imshow(transforms.ToPILImage()(denormalize(real_A[j]).cpu()))
                ax[0].set_title('Original Pokémon')
                ax[0].axis('off')

                ax[1].imshow(transforms.ToPILImage()(denormalize(fake_B[j]).cpu()))
                ax[1].set_title('Estilo Van Gogh')
                ax[1].axis('off')

                plt.tight_layout()
                plt.show()

                output_path = os.path.join(output_dir, f'img_{i+1}_{j+1}.png')
                fig.savefig(output_path)
                plt.close(fig)

output_dir = './output_images'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

visualize_results(dataloader, netG_A2B, output_dir)

# %% [markdown]
# ## 8. Comparação com Resultados Publicados por Terceiros
#
# Para avaliar a eficácia do modelo desenvolvido, é feita uma comparação com resultados obtidos por terceiros em trabalhos semelhantes que utilizaram GANs para transferência de estilo.
#
# ### Pix2Pix vs. CycleGAN
#
# O trabalho de Isola et al. (2017) com Pix2Pix apresentou resultados impressionantes na transferência de estilo, mas exigia pares de imagens correspondentes para treino. Em contrapartida, Zhu et al. (2017) desenvolveram o CycleGAN para superar esta limitação, permitindo a transferência de estilo sem a necessidade de pares de imagens.
#
# ### Resultados do Presente Trabalho
#
# - **Perdas**: As perdas dos discriminadores e geradores diminuíram ao longo do treino, similarmente ao observado nos trabalhos mencionados. Em particular, as flutuações nas perdas são consistentes com a natureza adversarial do treino, conforme descrito por Zhu et al. (2017).
# - **Qualidade das Imagens Geradas**: A qualidade das imagens geradas pelo modelo CycleGAN foi avaliada visualmente. As imagens estilizadas apresentaram características visuais do estilo Van Gogh, indicando que o modelo aprendeu a mapear corretamente as características do estilo.
#
# ### Comparação com Resultados Publicados
#
# - **Pix2Pix (Isola et al., 2017)**: No trabalho com Pix2Pix, a necessidade de pares de imagens limitava a aplicabilidade em cenários onde tais pares não estão disponíveis. O presente trabalho com CycleGAN superou esta limitação, permitindo a transferência de estilo sem a necessidade de pares correspondentes.
# - **CycleGAN (Zhu et al., 2017)**: O presente trabalho produziu resultados visualmente comparáveis aos apresentados por Zhu et al., com a vantagem adicional de demonstrar a aplicabilidade em um conjunto de dados específico (Pokémon e Van Gogh). As perdas ao longo do treino mostraram uma tendência decrescente, similar aos padrões observados no trabalho original do CycleGAN.
#
# ### Avaliação Quantitativa
#
# - **FID Score**: No trabalho de Zhu et al., a avaliação quantitativa das imagens geradas foi realizada utilizando o Fréchet Inception Distance (FID). Para uma comparação quantitativa mais rigorosa, seria interessante calcular o FID para as imagens geradas e compará-lo com os valores reportados por Zhu et al. (2017).
#
# ### Conclusão da Comparação
#
# Os resultados do presente trabalho estão alinhados com os resultados apresentados por Zhu et al. (2017), demonstrando a eficácia do CycleGAN para transferência de estilo sem pares de imagens correspondentes. A principal vantagem deste trabalho é a aplicação bem-sucedida do CycleGAN em um novo conjunto de dados, mostrando a versatilidade e robustez do modelo.
#
# Referências:
# - Isola, P., Zhu, J.-Y., Zhou, T., & Efros, A. A. (2017). Image-to-Image Translation with Conditional Adversarial Networks. In Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR).
# - Zhu, J.-Y., Park, T., Isola, P., & Efros, A. A. (2017). Unpaired Image-to-Image Translation using Cycle-Consistent Adversarial Networks. In Proceedings of the IEEE International Conference on Computer Vision (ICCV).

# %% [markdown]
# ## 9. Conclusão e Trabalhos Futuros
#
# ### Conclusão
#
# Neste projeto, foi utilizado o modelo CycleGAN para realizar a transferência de estilo de imagens de Pokémon para o estilo de pinturas de Van Gogh. O processo incluiu a preparação dos datasets, a definição das arquiteturas dos geradores e discriminadores, e o treino do modelo. As perdas foram monitorizadas ao longo do treino, observando-se uma diminuição geral nas perdas, indicando que os modelos estavam a melhorar.
#
# Visualizou-se o resultado final das transformações, onde as imagens de Pokémon foram estilizadas no estilo de Van Gogh, comprovando a eficácia do modelo treinado.
#
# ### Trabalhos Futuros
#
# Para trabalhos futuros, várias melhorias e extensões podem ser consideradas:
# - **Aumento do Dataset**: Utilizar um dataset maior e mais variado pode ajudar a melhorar a qualidade das imagens geradas.
# - **Ajustes de Hiperparâmetros**: Experimentar com diferentes hiperparâmetros, como a taxa de aprendizagem, o número de épocas e o tamanho dos lotes, para otimizar ainda mais o desempenho do modelo.
# - **Exploração de Outras Arquiteturas**: Investigar outras arquiteturas de GANs ou mesmo Autoencoders para ver se oferecem melhores resultados para este tipo de tarefa.
# - **Aplicação de Técnicas de Regularização**: Implementar técnicas de regularização como Dropout ou técnicas avançadas como Spectral Normalization para melhorar a estabilidade do treino.
# - **Avaliação Quantitativa**: Implementar métricas quantitativas para avaliar a qualidade das imagens geradas, como o Fréchet Inception Distance (FID) ou o Inception Score (IS).
#
# A abordagem apresentada neste trabalho pode ser aplicada a outras tarefas de transferência de estilo e oferece um ponto de partida sólido para investigações futuras.
